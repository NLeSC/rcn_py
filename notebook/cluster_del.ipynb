# %%
from pybliometrics.scopus import AbstractRetrieval

# %%
ab = AbstractRetrieval("10.1016/j.softx.2019.100263")
print(ab.title)
print(ab.authors)
# Out:
# pybliometrics: Scriptable bibliometrics using a Python interface to Scopus
# [Author(auid=57209617104, indexed_name='Rose M.E.', surname='Rose', given_name='Michael E.', affiliation='60105007'), Author(auid=7004212771, indexed_name='Kitchin J.R.', surname='Kitchin', given_name='John R.', affiliation='60027950')]

# %%
# "AuthorRetrieval" from pybliometrics package
author_id = 6603277503
au = AuthorRetrieval(author_id)
print(au)

# %%
au.affiliation_current
# Out:
# [Affiliation(id=112554118, parent=60023561, type='dept', relationship='author', afdispname=None, preferred_name='Department of Medicine', parent_preferred_name='Centre Hospitalier Universitaire Vaudois', country_code='che', country='Switzerland', address_part='Rue de Bugnon 21', city='Lausanne', state='VD', postal_code='1011', org_domain='lausanneuniversityhospital', org_URL='https://www.lausanneuniversityhospital.com/home')]

# %%
docs = pd.DataFrame(au.get_documents(refresh=10))
docs.columns
# Out:
# Index(['eid', 'doi', 'pii', 'pubmed_id', 'title', 'subtype',
#        'subtypeDescription', 'creator', 'afid', 'affilname',
#        'affiliation_city', 'affiliation_country', 'author_count',
#        'author_names', 'author_ids', 'author_afids', 'coverDate',
#        'coverDisplayDate', 'publicationName', 'issn', 'source_id', 'eIssn',
#        'aggregationType', 'volume', 'issueIdentifier', 'article_number',
#        'pageRange', 'description', 'authkeywords', 'citedby_count',
#        'openaccess', 'freetoread', 'freetoreadLabel', 'fund_acr', 'fund_no',
#        'fund_sponsor'],
#       dtype='object')

# %%
docs.coverDate
# Out:
# 0      2022-12-01
# 1      2022-12-01
# 2      2022-11-03
# 3      2022-10-01
# 4      2022-10-01
#           ...
# 167    1998-03-07
# 168    1997-01-01
# 169    1995-01-01
# 170    1994-01-01
# 171    1994-01-01
# Name: coverDate, Length: 172, dtype: object

# %%
# Delete documents that are too old
new_docs = docs[(docs.coverDate > '2018')]

# %%
new_docs["author_count"]
# Out:
# 0      97
# 1     100
# 2     100
# 3      93
# 4      94
#      ...
# 59     19
# 60     63
# 61     13
# 62     60
# 63     63
# Name: author_count, Length: 64, dtype: object

# %%
new_docs["new_author_count"] = [int(i) for i in new_docs.author_count]
new_docs["new_author_count"][0]
# Out:
# /tmp/ipykernel_20986/2511647989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_docs["new_author_count"] = [int(i) for i in new_docs.author_count]
# 97

# %%
my_docs = new_docs

# %%
# Delete documents with too many co-authorship relationships
my_docs = new_docs[(new_docs.new_author_count < 30)]

# %%
my_docs.reset_index(drop=True, inplace=True)

# %%
len(my_docs)
# Out:
# 64

# %%
# Get all the author info in the docs of one researcher
au_id = my_docs.author_ids
au_id
# Out:
# 0     57205100307;35069025400;9237623500;56146581800...
# 1     56653485300;55636643100;57226842887;5783073580...
# 2     56340274300;57193500089;6507087260;15753450100...
# 3     56735961400;57193523588;6506304249;8718959100;...
# 4     57200984619;56469814200;57358926700;8673143300...
#                             ...
# 59    57201479444;25651390500;57208011398;3611405450...
# 60    57189377649;6506014076;7004596986;7004121246;6...
# 61    7801624038;57208011398;57197467935;26427291000...
# 62    7006795092;7006085120;7103380067;19835874200;3...
# 63    6701433181;6602489733;35742245500;35372664600;...
# Name: author_ids, Length: 64, dtype: object

# %%
def find_coauthors(au_id):
    au = AuthorRetrieval(au_id)
    docs = pd.DataFrame(au.get_documents(refresh=10))
    # Delete documents that are too old
    new_docs = docs[(docs.coverDate > '2018')]
    # Delete documents with too many co-authorship relationships
    new_docs["new_author_count"] = [int(i) for i in new_docs.author_count]
    my_docs = new_docs[(new_docs.new_author_count < 10)]
    
    my_docs.reset_index(drop=True, inplace=True)

def get_hindex(au_id):
    au = AuthorRetrieval(au_id)
    return au.h_index
def get_auname(au_id):
    au = AuthorRetrieval(au_id)
    return au.given_name+' '+au.surname

# %%
# Obtain NL co-authors
coau_id2 = []
link2 = []
all_node2 = []
# group2 = {}
# team2 = 0
for i in au_id:
    coau_id2 = i.split(";")
    new_coau_id2 = []
    for j in coau_id2:
        aff = AuthorRetrieval(j).affiliation_current
        if AuthorRetrieval(j).affiliation_current:
            # Geo-filtering 
            if AuthorRetrieval(j).affiliation_current[0][7] == 'nld':
                all_node2.append(j)
                new_coau_id2.append(j)
     #   group[j] = team
    link2 = link2+list(itertools.combinations(new_coau_id2, 2))

# %%
coau_id2
# Out:
# ['57205100307',
#  '35069025400',
#  '9237623500',
#  '56146581800',
#  '24172784400',
#  '57905194900',
#  '57904184400',
#  '55324449300',
#  '56735961400',
#  '37030466200',
#  '22957488700',
#  '7102045384',
#  '24174793000',
#  '7102575527',
#  '6603304614',
#  '7003684255',
#  '55880489000',
#  '8718959100',
#  '18533651800',
#  '57220123078',
#  '7201383500',
#  '22933317900',
#  '35745452800',
#  '8534725900',
#  '7402340201',
#  '6507264676',
#  '57197725367',
#  '57195968514',
#  '6603277503',
#  '57211478548',
#  '35309243900',
#  '16142826900',
#  '6504624988',
#  '55978666700',
#  '7004627344',
#  '26430969300',
#  '12776997200',
#  '6603883785',
#  '57206774445',
#  '7003525887',
#  '7005051628',
#  '6506575476',
#  '6506296272',
#  '57831865800',
#  '22984831600',
#  '7006620847',
#  '7202350941',
#  '57521975900',
#  '7202406848',
#  '57220123784',
#  '6603816559',
#  '6602186102',
#  '6701349829',
#  '57193216712',
#  '57193523588',
#  '56764357800',
#  '16033216900',
#  '14022858600',
#  '6506992865',
#  '35964694300',
#  '36770934000',
#  '10139630600',
#  '56690563900',
#  '57220118224',
#  '57220121596',
#  '8764310000',
#  '57220118928',
#  '57214407068',
#  '56236092800',
#  '12761433100',
#  '7102302577',
#  '35243190200',
#  '57831542700',
#  '6506369481',
#  '56763745900',
#  '8130986200',
#  '56665106900',
#  '56764609400',
#  '7003359126',
#  '8548046300',
#  '7003539122',
#  '7004103816',
#  '35308020900',
#  '14027398200',
#  '7004016445',
#  '57832035200',
#  '25625513600',
#  '8909777500',
#  '7006169559',
#  '6506429791',
#  '57226815928',
#  '6602099849',
#  '7004653943',
#  '55676122800',
#  '56763535500',
#  '7202944848',
#  '14825991700']

# %%
def getCombinations(seq):
    combinations = list()
    seq = seq.sort()
    for i in range(0,len(seq)):
        for j in range(i+1,len(seq)):
            combinations.append([seq[i],seq[j]])
    return combinations

# %%
AuthorRetrieval(author_id).affiliation_current
# Out:
# [Affiliation(id=112554118, parent=60023561, type='dept', relationship='author', afdispname=None, preferred_name='Department of Medicine', parent_preferred_name='Centre Hospitalier Universitaire Vaudois', country_code='che', country='Switzerland', address_part='Rue de Bugnon 21', city='Lausanne', state='VD', postal_code='1011', org_domain='lausanneuniversityhospital', org_URL='https://www.lausanneuniversityhospital.com/home')]

# %%
author_id = 6603277503
node_retrieved = []

def nld_coauthor(author_id, depth, node_retrieved):
    au = AuthorRetrieval(author_id)
    docs = pd.DataFrame(au.get_documents())
    # Access to documents for the last five years
    new_docs = docs[(docs.coverDate > '2018')]
    au_id = new_docs.author_ids
    
    link = []
    all_node = []

    node_retrieved.append(author_id)
    
    for i in au_id:
        coau_id = i.split(";")
        coau_id = list(map(int, coau_id))
        new_coau_id = []
        for j in coau_id:
            aff = AuthorRetrieval(j).affiliation_current
            if AuthorRetrieval(j).affiliation_current:
                # Geo-filtering 
                if AuthorRetrieval(j).affiliation_current[0][7] == 'nld':
                    if j not in all_node:
                        all_node.append(j)
                    new_coau_id.append(j)
                    
        sorted_new_coauid = list(map(int, new_coau_id))
        sorted_new_coauid.sort()
        link = link+list(itertools.combinations(sorted_new_coauid, 2))
        # Do recursion (increase depth of the network)
        if depth > 0:
            for j in sorted_new_coauid:
                if j not in node_retrieved:
                    nld_coauthor(j, depth-1)
    return all_node, link

# %%
# slow
x,y = nld_coauthor(author_id, 1, node_retrieved)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20986/4163763996.py in <module>
#       1 # slow
# ----> 2 x,y = nld_coauthor(author_id, 1, node_retrieved)
#       3 print(x)
#
# /tmp/ipykernel_20986/3292528509.py in nld_coauthor(author_id, depth, node_retrieved)
#      33             for j in sorted_new_coauid:
#      34                 if j not in node_retrieved:
# ---> 35                     nld_coauthor(j, depth-1)
#      36     return all_node, link
#      37
#
# TypeError: nld_coauthor() missing 1 required positional argument: 'node_retrieved'

# %%
x2,y2 = nld_coauthor(57203646157, 0, node_retrieved)

# %%
print(x2)
# Out:
# [57203646157, 57221791778, 7005930079, 7006279060, 57537265700, 57218949992, 35378641700, 6701804604, 24075711800, 8050973500, 7005763178, 24528146600, 55840875500, 57003590900, 14219583800, 57214743523, 57202056973, 6602187919]

# %%
# Get all the subject areas of every node
counter_node2 = Counter(all_node2)
areas2 = []
for i in counter_node2:
    au_info2 = AuthorRetrieval(i)
    subjects2 = au_info2.subject_areas
    areas2.append(subjects2)
areas2

# %%
docs.coverDate
# Out:
# 0      2022-12-01
# 1      2022-12-01
# 2      2022-11-03
# 3      2022-10-01
# 4      2022-10-01
#           ...
# 167    1998-03-07
# 168    1997-01-01
# 169    1995-01-01
# 170    1994-01-01
# 171    1994-01-01
# Name: coverDate, Length: 172, dtype: object

# %%
new_au = AuthorRetrieval(6603277503)
new_docs =pd.DataFrame(new_au.get_documents())
#new_docs = pd.DataFrame(new_au.get_documents(refresh=10))
#new_coauthors = pd.DataFrame(new_au.get_coauthors())
#print(new_au.given_name+' '+new_au.surname)

# %%
counter_node2 = Counter(all_node2)
areas2 = []
for i in counter_node2:
    au_info2 = AuthorRetrieval(i)
    subjects2 = au_info2.subject_areas
    areas2.append(subjects2)
areas2
# Out:
# [[Subjectarea(area='Sociology and Political Science', abbreviation='SOCI', code=3312),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Life-span and Life-course Studies', abbreviation='SOCI', code=3319),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Neuropsychology and Physiological Psychology', abbreviation='PSYC', code=3206),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Behavioral Neuroscience', abbreviation='NEUR', code=2802),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Developmental and Educational Psychology', abbreviation='PSYC', code=3204),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Applied Psychology', abbreviation='PSYC', code=3202),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Social Sciences (miscellaneous)', abbreviation='SOCI', code=3301),
#   Subjectarea(area='Social Psychology', abbreviation='PSYC', code=3207),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Health (social science)', abbreviation='SOCI', code=3306),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Public Administration', abbreviation='SOCI', code=3321),
#   Subjectarea(area='Psychology (all)', abbreviation='PSYC', code=3200),
#   Subjectarea(area='Physiology (medical)', abbreviation='MEDI', code=2737),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Experimental and Cognitive Psychology', abbreviation='PSYC', code=3205),
#   Subjectarea(area='Neurology', abbreviation='NEUR', code=2808),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Education', abbreviation='SOCI', code=3304),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Obstetrics and Gynecology', abbreviation='MEDI', code=2729),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Clinical Psychology', abbreviation='PSYC', code=3203),
#   Subjectarea(area='Anthropology', abbreviation='SOCI', code=3314),
#   Subjectarea(area='Pathology and Forensic Medicine', abbreviation='MEDI', code=2734),
#   Subjectarea(area='Toxicology', abbreviation='PHAR', code=3005),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739)],
#  [Subjectarea(area='Computer Science (all)', abbreviation='COMP', code=1700),
#   Subjectarea(area='Biological Psychiatry', abbreviation='NEUR', code=2803),
#   Subjectarea(area='Computational Mathematics', abbreviation='MATH', code=2605),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Developmental Neuroscience', abbreviation='NEUR', code=2806),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (miscellaneous)', abbreviation='BIOC', code=1301),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Social Psychology', abbreviation='PSYC', code=3207),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Structural Biology', abbreviation='BIOC', code=1315),
#   Subjectarea(area='Education', abbreviation='SOCI', code=3304),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Developmental Biology', abbreviation='BIOC', code=1309),
#   Subjectarea(area='Aging', abbreviation='BIOC', code=1302),
#   Subjectarea(area='Biochemistry (medical)', abbreviation='MEDI', code=2704),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Advanced and Specialized Nursing', abbreviation='NURS', code=2902),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Statistics and Probability', abbreviation='MATH', code=2613),
#   Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Geriatrics and Gerontology', abbreviation='MEDI', code=2717),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Health (social science)', abbreviation='SOCI', code=3306),
#   Subjectarea(area='Computer Science Applications', abbreviation='COMP', code=1706),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Experimental and Cognitive Psychology', abbreviation='PSYC', code=3205),
#   Subjectarea(area='Behavioral Neuroscience', abbreviation='NEUR', code=2802),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Applied Mathematics', abbreviation='MATH', code=2604),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728)],
#  [Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000)],
#  [Subjectarea(area='Physical and Theoretical Chemistry', abbreviation='CHEM', code=1606),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Nutrition and Dietetics', abbreviation='NURS', code=2916),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Inorganic Chemistry', abbreviation='CHEM', code=1604),
#   Subjectarea(area='Developmental and Educational Psychology', abbreviation='PSYC', code=3204),
#   Subjectarea(area='Endocrine and Autonomic Systems', abbreviation='NEUR', code=2807),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Aging', abbreviation='BIOC', code=1302),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Behavioral Neuroscience', abbreviation='NEUR', code=2802),
#   Subjectarea(area='Spectroscopy', abbreviation='CHEM', code=1607),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Social Psychology', abbreviation='PSYC', code=3207),
#   Subjectarea(area='Computer Science Applications', abbreviation='COMP', code=1706),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Catalysis', abbreviation='CENG', code=1503),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Geriatrics and Gerontology', abbreviation='MEDI', code=2717),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Orthopedics and Sports Medicine', abbreviation='MEDI', code=2732),
#   Subjectarea(area='Histology', abbreviation='MEDI', code=2722),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Anthropology', abbreviation='SOCI', code=3314),
#   Subjectarea(area='Organic Chemistry', abbreviation='CHEM', code=1605),
#   Subjectarea(area='Experimental and Cognitive Psychology', abbreviation='PSYC', code=3205),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Anatomy', abbreviation='MEDI', code=2702),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724)],
#  [Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Health, Toxicology and Mutagenesis', abbreviation='ENVI', code=2307),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Plant Science', abbreviation='AGRI', code=1110),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Spectroscopy', abbreviation='CHEM', code=1607),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Bioengineering', abbreviation='CENG', code=1502),
#   Subjectarea(area='Biological Psychiatry', abbreviation='NEUR', code=2803),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Toxicology', abbreviation='PHAR', code=3005),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Organic Chemistry', abbreviation='CHEM', code=1605),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Drug Discovery', abbreviation='PHAR', code=3002),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Neurology', abbreviation='NEUR', code=2808),
#   Subjectarea(area='Developmental Biology', abbreviation='BIOC', code=1309),
#   Subjectarea(area='Ophthalmology', abbreviation='MEDI', code=2731),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Embryology', abbreviation='MEDI', code=2710),
#   Subjectarea(area='Pharmaceutical Science', abbreviation='PHAR', code=3003),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Pharmacy', abbreviation='HEAL', code=3611)],
#  [Subjectarea(area='Pathology and Forensic Medicine', abbreviation='MEDI', code=2734),
#   Subjectarea(area='Health Professions  (all)', abbreviation='HEAL', code=3600),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Plant Science', abbreviation='AGRI', code=1110),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Drug Discovery', abbreviation='PHAR', code=3002),
#   Subjectarea(area='Statistics, Probability and Uncertainty', abbreviation='DECI', code=1804),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Applied Mathematics', abbreviation='MATH', code=2604),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Rehabilitation', abbreviation='MEDI', code=2742),
#   Subjectarea(area='Physiology (medical)', abbreviation='MEDI', code=2737),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Agricultural and Biological Sciences (miscellaneous)', abbreviation='AGRI', code=1101),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Pharmaceutical Science', abbreviation='PHAR', code=3003),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Leadership and Management', abbreviation='NURS', code=2911),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Advanced and Specialized Nursing', abbreviation='NURS', code=2902),
#   Subjectarea(area='Biochemistry (medical)', abbreviation='MEDI', code=2704),
#   Subjectarea(area='Oral Surgery', abbreviation='DENT', code=3504),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Periodontics', abbreviation='DENT', code=3506),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Otorhinolaryngology', abbreviation='MEDI', code=2733)]]

# %%
all_authors = list(set(all_node2))
len(all_authors)
# Out:
# 6

# %%
au_subject2 = []
for i in range(len(areas2)):
    subject_list2 = []
    for j in areas2[i]:
        subject_list2.append(j.abbreviation)
    au_subject2.append(Counter(subject_list2).most_common(1)[0][0])
    
list(set(au_subject2))
# Out:
# ['MEDI', 'MULT']

# %%
# Obtain co-authors
coau_id = []
link = []
all_node = []
group = {}
team = 0
for i in au_id:
    coau_id = i.split(";")
    new_coau_id = []
    for j in coau_id:
        aff = AuthorRetrieval(j).affiliation_current
        if AuthorRetrieval(j).affiliation_current:
            #if AuthorRetrieval(j).affiliation_current[0][7] == 'nld':
                all_node.append(j)
                new_coau_id.append(j)
     #   group[j] = team
    link = link+list(itertools.combinations(new_coau_id, 2))
    team = team+1

# %%
len(all_node)
# Out:
# 363

# %%
counter_node = Counter(all_node)
areas = []
for i in counter_node:
    au_info = AuthorRetrieval(i)
    subjects = au_info.subject_areas
    areas.append(subjects)
areas
# Out:
# [[Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Obstetrics and Gynecology', abbreviation='MEDI', code=2729),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Health, Toxicology and Mutagenesis', abbreviation='ENVI', code=2307),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Anesthesiology and Pain Medicine', abbreviation='MEDI', code=2703),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Toxicology', abbreviation='PHAR', code=3005),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726)],
#  [Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725)],
#  [Subjectarea(area='Arts and Humanities (miscellaneous)', abbreviation='ARTS', code=1201),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Biomaterials', abbreviation='MATE', code=2502),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Neurology', abbreviation='NEUR', code=2808),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Oral Surgery', abbreviation='DENT', code=3504),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Instrumentation', abbreviation='PHYS', code=3105),
#   Subjectarea(area='Nutrition and Dietetics', abbreviation='NURS', code=2916),
#   Subjectarea(area='Library and Information Sciences', abbreviation='SOCI', code=3309),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Anesthesiology and Pain Medicine', abbreviation='MEDI', code=2703),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Mathematical Physics', abbreviation='MATH', code=2610),
#   Subjectarea(area='Physiology (medical)', abbreviation='MEDI', code=2737),
#   Subjectarea(area='Computer Science Applications', abbreviation='COMP', code=1706),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Statistics and Probability', abbreviation='MATH', code=2613),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Endocrinology', abbreviation='BIOC', code=1310),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Emergency Nursing', abbreviation='NURS', code=2907),
#   Subjectarea(area='Information Systems', abbreviation='COMP', code=1710),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Statistics, Probability and Uncertainty', abbreviation='DECI', code=1804),
#   Subjectarea(area='Otorhinolaryngology', abbreviation='MEDI', code=2733),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Emergency Medicine', abbreviation='MEDI', code=2711),
#   Subjectarea(area='Biophysics', abbreviation='BIOC', code=1304),
#   Subjectarea(area='Sensory Systems', abbreviation='NEUR', code=2809),
#   Subjectarea(area='Bioengineering', abbreviation='CENG', code=1502),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Plant Science', abbreviation='AGRI', code=1110),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Education', abbreviation='SOCI', code=3304),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403)],
#  [Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Food Science', abbreviation='AGRI', code=1106),
#   Subjectarea(area='Environmental Science (all)', abbreviation='ENVI', code=2300),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Statistics and Probability', abbreviation='MATH', code=2613),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Insect Science', abbreviation='AGRI', code=1109),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Computer Science Applications', abbreviation='COMP', code=1706),
#   Subjectarea(area='Computational Mathematics', abbreviation='MATH', code=2605),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725)],
#  [Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736)],
#  [Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Physiology (medical)', abbreviation='MEDI', code=2737),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Health, Toxicology and Mutagenesis', abbreviation='ENVI', code=2307),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Spectroscopy', abbreviation='CHEM', code=1607),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Health Information Management', abbreviation='HEAL', code=3605),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Pathology and Forensic Medicine', abbreviation='MEDI', code=2734),
#   Subjectarea(area='Organic Chemistry', abbreviation='CHEM', code=1605),
#   Subjectarea(area='Agricultural and Biological Sciences (miscellaneous)', abbreviation='AGRI', code=1101),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Psychology (all)', abbreviation='PSYC', code=3200),
#   Subjectarea(area='Insect Science', abbreviation='AGRI', code=1109),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Emergency Medicine', abbreviation='MEDI', code=2711),
#   Subjectarea(area='Endocrinology', abbreviation='BIOC', code=1310),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Health Informatics', abbreviation='MEDI', code=2718),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Biophysics', abbreviation='BIOC', code=1304),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Toxicology', abbreviation='PHAR', code=3005)],
#  [Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Gerontology', abbreviation='NURS', code=2909),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Advanced and Specialized Nursing', abbreviation='NURS', code=2902),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Aging', abbreviation='BIOC', code=1302),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Health (social science)', abbreviation='SOCI', code=3306),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Immunology and Microbiology (miscellaneous)', abbreviation='IMMU', code=2401),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Geriatrics and Gerontology', abbreviation='MEDI', code=2717),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406)],
#  [Subjectarea(area='Veterinary (miscellaneous)', abbreviation='VETE', code=3401),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Biochemistry (medical)', abbreviation='MEDI', code=2704),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Plant Science', abbreviation='AGRI', code=1110),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Agronomy and Crop Science', abbreviation='AGRI', code=1102),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723)],
#  [Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Neurology', abbreviation='NEUR', code=2808),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000)],
#  [Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406)],
#  [Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Emergency Medicine', abbreviation='MEDI', code=2711),
#   Subjectarea(area='Health Informatics', abbreviation='MEDI', code=2718),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Rehabilitation', abbreviation='MEDI', code=2742),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Health Information Management', abbreviation='HEAL', code=3605),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740)],
#  [Subjectarea(area='Education', abbreviation='SOCI', code=3304),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725)],
#  [Subjectarea(area='Assessment and Diagnosis', abbreviation='NURS', code=2903),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Health Information Management', abbreviation='HEAL', code=3605),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Pathology and Forensic Medicine', abbreviation='MEDI', code=2734),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Care Planning', abbreviation='NURS', code=2904),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Health Informatics', abbreviation='MEDI', code=2718),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Leadership and Management', abbreviation='NURS', code=2911),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Anesthesiology and Pain Medicine', abbreviation='MEDI', code=2703),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Fundamentals and Skills', abbreviation='NURS', code=2908),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720)],
#  [Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Veterinary (miscellaneous)', abbreviation='VETE', code=3401),
#   Subjectarea(area='Health Informatics', abbreviation='MEDI', code=2718),
#   Subjectarea(area='Management, Monitoring, Policy and Law', abbreviation='ENVI', code=2308),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Nutrition and Dietetics', abbreviation='NURS', code=2916),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Waste Management and Disposal', abbreviation='ENVI', code=2311),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Environmental Chemistry', abbreviation='ENVI', code=2304),
#   Subjectarea(area='Agricultural and Biological Sciences (miscellaneous)', abbreviation='AGRI', code=1101),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Health Information Management', abbreviation='HEAL', code=3605),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Water Science and Technology', abbreviation='ENVI', code=2312),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Pathology and Forensic Medicine', abbreviation='MEDI', code=2734),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Insect Science', abbreviation='AGRI', code=1109),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Environmental Engineering', abbreviation='ENVI', code=2305),
#   Subjectarea(area='Computer Science Applications', abbreviation='COMP', code=1706),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Biochemistry (medical)', abbreviation='MEDI', code=2704),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Electrochemistry', abbreviation='CHEM', code=1603),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Food Science', abbreviation='AGRI', code=1106),
#   Subjectarea(area='Biophysics', abbreviation='BIOC', code=1304),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Animal Science and Zoology', abbreviation='AGRI', code=1103),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Geography, Planning and Development', abbreviation='SOCI', code=3305),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Physiology (medical)', abbreviation='MEDI', code=2737),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Immunology and Microbiology (miscellaneous)', abbreviation='IMMU', code=2401),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='History and Philosophy of Science', abbreviation='ARTS', code=1207),
#   Subjectarea(area='Obstetrics and Gynecology', abbreviation='MEDI', code=2729),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Drug Discovery', abbreviation='PHAR', code=3002),
#   Subjectarea(area='Environmental Science (all)', abbreviation='ENVI', code=2300),
#   Subjectarea(area='Safety, Risk, Reliability and Quality', abbreviation='ENGI', code=2213),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Medical Laboratory Technology', abbreviation='HEAL', code=3607),
#   Subjectarea(area='Chemical Engineering (all)', abbreviation='CENG', code=1500),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Pollution', abbreviation='ENVI', code=2310),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Reproductive Medicine', abbreviation='MEDI', code=2743),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303)],
#  [Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Modeling and Simulation', abbreviation='MATH', code=2611),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Bioengineering', abbreviation='CENG', code=1502),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Oncology (nursing)', abbreviation='NURS', code=2917),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Insect Science', abbreviation='AGRI', code=1109),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726)],
#  [Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Physiology (medical)', abbreviation='MEDI', code=2737),
#   Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Arts and Humanities (miscellaneous)', abbreviation='ARTS', code=1201),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Health, Toxicology and Mutagenesis', abbreviation='ENVI', code=2307),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Chemical Engineering (all)', abbreviation='CENG', code=1500),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Pharmaceutical Science', abbreviation='PHAR', code=3003),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Psychiatry and Mental Health', abbreviation='MEDI', code=2738),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Neurology', abbreviation='NEUR', code=2808),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Pathology and Forensic Medicine', abbreviation='MEDI', code=2734),
#   Subjectarea(area='Statistics and Probability', abbreviation='MATH', code=2613),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Modeling and Simulation', abbreviation='MATH', code=2611),
#   Subjectarea(area='Drug Discovery', abbreviation='PHAR', code=3002),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Histology', abbreviation='MEDI', code=2722),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Applied Mathematics', abbreviation='MATH', code=2604),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Endocrinology', abbreviation='BIOC', code=1310),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Bioengineering', abbreviation='CENG', code=1502),
#   Subjectarea(area='Insect Science', abbreviation='AGRI', code=1109),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Toxicology', abbreviation='PHAR', code=3005),
#   Subjectarea(area='Oncology (nursing)', abbreviation='NURS', code=2917),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Endocrinology, Diabetes and Metabolism', abbreviation='MEDI', code=2712),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Anatomy', abbreviation='MEDI', code=2702),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308)],
#  [Subjectarea(area='Water Science and Technology', abbreviation='ENVI', code=2312),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Environmental Science (all)', abbreviation='ENVI', code=2300),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Biochemistry (medical)', abbreviation='MEDI', code=2704),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Medical Laboratory Technology', abbreviation='HEAL', code=3607),
#   Subjectarea(area='Chemical Engineering (all)', abbreviation='CENG', code=1500),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Nutrition and Dietetics', abbreviation='NURS', code=2916),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Environmental Engineering', abbreviation='ENVI', code=2305),
#   Subjectarea(area='Insect Science', abbreviation='AGRI', code=1109),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
# ...
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Biochemistry (medical)', abbreviation='MEDI', code=2704),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100)],
#  [Subjectarea(area='Organic Chemistry', abbreviation='CHEM', code=1605),
#   Subjectarea(area='Pediatrics, Perinatology and Child Health', abbreviation='MEDI', code=2735),
#   Subjectarea(area='Engineering (miscellaneous)', abbreviation='ENGI', code=2201),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Health Informatics', abbreviation='MEDI', code=2718),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Emergency Medicine', abbreviation='MEDI', code=2711),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Fluid Flow and Transfer Processes', abbreviation='CENG', code=1507),
#   Subjectarea(area='Surgery', abbreviation='MEDI', code=2746),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Nursing (all)', abbreviation='NURS', code=2900),
#   Subjectarea(area='Chemical Engineering (all)', abbreviation='CENG', code=1500),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Inorganic Chemistry', abbreviation='CHEM', code=1604),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Catalysis', abbreviation='CENG', code=1503),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Biotechnology', abbreviation='BIOC', code=1305),
#   Subjectarea(area='Computational Mathematics', abbreviation='MATH', code=2605),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Spectroscopy', abbreviation='CHEM', code=1607),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Drug Discovery', abbreviation='PHAR', code=3002),
#   Subjectarea(area='Environmental Science (all)', abbreviation='ENVI', code=2300),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Clinical Biochemistry', abbreviation='BIOC', code=1308),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Immunology and Microbiology (miscellaneous)', abbreviation='IMMU', code=2401),
#   Subjectarea(area='Bioengineering', abbreviation='CENG', code=1502),
#   Subjectarea(area='Radiological and Ultrasound Technology', abbreviation='HEAL', code=3614),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Physiology', abbreviation='BIOC', code=1314),
#   Subjectarea(area='Physical and Theoretical Chemistry', abbreviation='CHEM', code=1606),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Instrumentation', abbreviation='PHYS', code=3105),
#   Subjectarea(area='Statistics and Probability', abbreviation='MATH', code=2613),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Health Information Management', abbreviation='HEAL', code=3605),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Geriatrics and Gerontology', abbreviation='MEDI', code=2717),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Analytical Chemistry', abbreviation='CHEM', code=1602),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Computer Science Applications', abbreviation='COMP', code=1706),
#   Subjectarea(area='Ophthalmology', abbreviation='MEDI', code=2731),
#   Subjectarea(area='Process Chemistry and Technology', abbreviation='CENG', code=1508),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303)],
#  [Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Developmental Biology', abbreviation='BIOC', code=1309),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Structural Biology', abbreviation='BIOC', code=1315),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Agricultural and Biological Sciences (miscellaneous)', abbreviation='AGRI', code=1101),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403)],
#  [Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Radiology, Nuclear Medicine and Imaging', abbreviation='MEDI', code=2741),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Applied Microbiology and Biotechnology', abbreviation='IMMU', code=2402),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Veterinary (all)', abbreviation='VETE', code=3400),
#   Subjectarea(area='Hepatology', abbreviation='MEDI', code=2721),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Aging', abbreviation='BIOC', code=1302),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='History and Philosophy of Science', abbreviation='ARTS', code=1207),
#   Subjectarea(area='Cardiology and Cardiovascular Medicine', abbreviation='MEDI', code=2705),
#   Subjectarea(area='Modeling and Simulation', abbreviation='MATH', code=2611),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Gastroenterology', abbreviation='MEDI', code=2715),
#   Subjectarea(area='Agricultural and Biological Sciences (all)', abbreviation='AGRI', code=1100),
#   Subjectarea(area='Oncology (nursing)', abbreviation='NURS', code=2917),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Biophysics', abbreviation='BIOC', code=1304),
#   Subjectarea(area='Pharmaceutical Science', abbreviation='PHAR', code=3003),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Critical Care and Intensive Care Medicine', abbreviation='MEDI', code=2706),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Pulmonary and Respiratory Medicine', abbreviation='MEDI', code=2740),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Transplantation', abbreviation='MEDI', code=2747),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Health (social science)', abbreviation='SOCI', code=3306),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Geriatrics and Gerontology', abbreviation='MEDI', code=2717),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Statistics and Probability', abbreviation='MATH', code=2613),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Pharmacology, Toxicology and Pharmaceutics (all)', abbreviation='PHAR', code=3000)],
#  [Subjectarea(area='Modeling and Simulation', abbreviation='MATH', code=2611),
#   Subjectarea(area='Public Health, Environmental and Occupational Health', abbreviation='MEDI', code=2739),
#   Subjectarea(area='Law', abbreviation='SOCI', code=3308),
#   Subjectarea(area='Biochemistry', abbreviation='BIOC', code=1303),
#   Subjectarea(area='Ecology, Evolution, Behavior and Systematics', abbreviation='AGRI', code=1105),
#   Subjectarea(area='Virology', abbreviation='IMMU', code=2406),
#   Subjectarea(area='Drug Discovery', abbreviation='PHAR', code=3002),
#   Subjectarea(area='Immunology', abbreviation='IMMU', code=2403),
#   Subjectarea(area='Molecular Medicine', abbreviation='BIOC', code=1313),
#   Subjectarea(area='Health Policy', abbreviation='MEDI', code=2719),
#   Subjectarea(area='Histology', abbreviation='MEDI', code=2722),
#   Subjectarea(area='Infectious Diseases', abbreviation='MEDI', code=2725),
#   Subjectarea(area='Neurology (clinical)', abbreviation='MEDI', code=2728),
#   Subjectarea(area='Biomedical Engineering', abbreviation='ENGI', code=2204),
#   Subjectarea(area='Information Systems', abbreviation='COMP', code=1710),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (all)', abbreviation='BIOC', code=1300),
#   Subjectarea(area='Dermatology', abbreviation='MEDI', code=2708),
#   Subjectarea(area='Rheumatology', abbreviation='MEDI', code=2745),
#   Subjectarea(area='Medicine (miscellaneous)', abbreviation='MEDI', code=2701),
#   Subjectarea(area='Health Informatics', abbreviation='MEDI', code=2718),
#   Subjectarea(area='Health Information Management', abbreviation='HEAL', code=3605),
#   Subjectarea(area='Cell Biology', abbreviation='BIOC', code=1307),
#   Subjectarea(area='Computational Theory and Mathematics', abbreviation='COMP', code=1703),
#   Subjectarea(area='Pharmacology', abbreviation='PHAR', code=3004),
#   Subjectarea(area='Nephrology', abbreviation='MEDI', code=2727),
#   Subjectarea(area='Cellular and Molecular Neuroscience', abbreviation='NEUR', code=2804),
#   Subjectarea(area='Safety, Risk, Reliability and Quality', abbreviation='ENGI', code=2213),
#   Subjectarea(area='Oncology', abbreviation='MEDI', code=2730),
#   Subjectarea(area='Hematology', abbreviation='MEDI', code=2720),
#   Subjectarea(area='Chemistry (all)', abbreviation='CHEM', code=1600),
#   Subjectarea(area='Parasitology', abbreviation='IMMU', code=2405),
#   Subjectarea(area='Internal Medicine', abbreviation='MEDI', code=2724),
#   Subjectarea(area='Medicine (all)', abbreviation='MEDI', code=2700),
#   Subjectarea(area='Genetics', abbreviation='BIOC', code=1311),
#   Subjectarea(area='Biochemistry, Genetics and Molecular Biology (miscellaneous)', abbreviation='BIOC', code=1301),
#   Subjectarea(area='Cancer Research', abbreviation='BIOC', code=1306),
#   Subjectarea(area='Microbiology (medical)', abbreviation='MEDI', code=2726),
#   Subjectarea(area='Ecology', abbreviation='ENVI', code=2303),
#   Subjectarea(area='Genetics (clinical)', abbreviation='MEDI', code=2716),
#   Subjectarea(area='Physics and Astronomy (all)', abbreviation='PHYS', code=3100),
#   Subjectarea(area='Multidisciplinary', abbreviation='MULT', code=1000),
#   Subjectarea(area='Immunology and Microbiology (all)', abbreviation='IMMU', code=2400),
#   Subjectarea(area='Pharmacology (medical)', abbreviation='MEDI', code=2736),
#   Subjectarea(area='Epidemiology', abbreviation='MEDI', code=2713),
#   Subjectarea(area='Molecular Biology', abbreviation='BIOC', code=1312),
#   Subjectarea(area='Immunology and Allergy', abbreviation='MEDI', code=2723),
#   Subjectarea(area='Computer Networks and Communications', abbreviation='COMP', code=1705),
#   Subjectarea(area='Neuroscience (all)', abbreviation='NEUR', code=2800),
#   Subjectarea(area='Microbiology', abbreviation='IMMU', code=2404)]]

# %%
au_subject = []
for i in range(len(areas)):
    subject_list = []
    for j in areas[i]:
        subject_list.append(j.abbreviation)
    au_subject.append(Counter(subject_list).most_common(1)[0][0])

# %%
au_areas = {}
for n in range(len(all_authors)):
    au_areas[all_authors[n]] = au_subject[n]

# %%
# Assign groups
exist_area = {}
au_group = {}
group_num = 0
for i in au_areas:
    if au_areas[i] not in exist_area:
        exist_area[au_areas[i]] = group_num
        au_group[i] = group_num
        group_num += 1
    else:
        au_group[i] = exist_area[au_areas[i]]

# %%
# Initialize nextworkx
GG = nx.Graph()
GG.add_edges_from(link)

# %%
sources = []
targets = []
weights = []

for i in link:
    sources.append(i[0])
    targets.append(i[1])
    weights.append(link.count(i))

# %%
# Pyvis network
N = Network(height=800, width="100%", bgcolor="#222222", font_color="white", select_menu=True, notebook = True)
N.toggle_hide_edges_on_drag(False)
N.barnes_hut()

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    N.add_node(src, src, title=src, group = au_group[src])
    N.add_node(dst, dst, title=dst, group = au_group[dst])
    N.add_edge(src, dst, value=w)

neighbor_map = N.get_adj_list()

# add neighbor data to node hover data
for node in N.nodes:
    neighbors = []
    for neighbor_id in neighbor_map[node["id"]]:
        neigh = AuthorRetrieval(neighbor_id)
        neighbors.append(neigh.given_name+' '+neigh.surname)
    #node["title"] = " Neighbors: \n" + " \n".join(neighbors)
    node["title"] = "Link to the author’s API page:\n" + AuthorRetrieval(node["id"]).self_link
    node["value"] = get_hindex(node["id"])
    node["label"] = AuthorRetrieval(node["id"]).given_name+' '+AuthorRetrieval(node["id"]).surname
    # node["group"] = group[node["id"]]
    # node["font_size"] = get_hindex(node["id"])

N.show("scopus226.html")
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
#         <iframe
#             width="100%"
#             height="800"
#             src="scopus226.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
G = nx.DiGraph()

edge_data = zip(sources, targets, weights)

for e in edge_data:
    src = e[0]
    dst = e[1]
    w = e[2]

    G.add_node(src, src, title=src, group = au_group[src])
    G.add_node(dst, dst, title=dst, group = au_group[dst])
    G.add_edge(src, dst, value=w)

neighbor_map = G.get_adj_list()

# add neighbor data to node hover data
for node in G.nodes:
    neighbors = []
    for neighbor_id in neighbor_map[node["id"]]:
        neigh = AuthorRetrieval(neighbor_id)
        neighbors.append(neigh.given_name+' '+neigh.surname)
    #node["title"] = " Neighbors: \n" + " \n".join(neighbors)
    node["title"] = "Link to the author’s API page:\n" + AuthorRetrieval(node["id"]).self_link
    node["value"] = get_hindex(node["id"])
    node["label"] = AuthorRetrieval(node["id"]).given_name+' '+AuthorRetrieval(node["id"]).surname)

nx.write_gexf(G, 'scopus1078.gexf')

# %%
def build_graph(G, au_id, depth, bredth, last_author=[]):
    author_search = scholarly.search_author_id(sch_id)
    author = scholarly.fill(author_search, sections=['coauthors','indices','counts'])
    author_name = author['name']
    author_hin = author['hindex']
    author_ncite = author['citedby']
    G.add_node(author_name, hindex=author_hin, name=author_name, ncite=author_ncite)
    print("now at %s, depth=%d"%(author_name, depth))
    if depth>0:
        for coauthor in author['coauthors'][:int(bredth)]:
            G.add_edge(author_name,coauthor['name'])
            if coauthor['name'] not in last_author:
                last_author.append(author_name)
                build_graph(G, coauthor['scholar_id'], depth-1, bredth, last_author)

# %%
pos = nx.spring_layout(GG)

plt.figure(figsize=(100,80))

sizes = [ 20*GG.degree[node]+5 for node in GG.nodes]
dolphin_pr = nx.pagerank(GG)
colors = [ dolphin_pr[node] for node in GG.nodes]

pos = nx.spring_layout(GG)
s = nx.draw_networkx_nodes(GG, pos, node_size=sizes, node_color= colors,cmap='inferno')
cbar = plt.colorbar(s)
nx.draw_networkx_edges(GG, pos, edge_color='#4682B4')

#label top ten of centrality
centrality = dict(GG.degree())
degtop = sorted(centrality.keys(), key= lambda x:-centrality[x])[:50]
new_labels = {node:node for node in degtop}
nx.draw_networkx_labels(GG, pos, labels=new_labels, font_size=50)


plt.title('Mapping coauthorship', size = 50);
plt.axis('off');

# %%
def build_graph(G, au_id, depth, bredth, last_author=[]):
    author_search = scholarly.search_author_id(sch_id)
    author = scholarly.fill(author_search, sections=['coauthors','indices','counts'])
    author_name = author['name']
    author_hin = author['hindex']
    author_ncite = author['citedby']
    G.add_node(author_name, hindex=author_hin, name=author_name, ncite=author_ncite)
    print("now at %s, depth=%d"%(author_name, depth))
    if depth>0:
        for coauthor in author['coauthors'][:int(bredth)]:
            G.add_edge(author_name,coauthor['name'])
            if coauthor['name'] not in last_author:
                last_author.append(author_name)
                build_graph(G, coauthor['scholar_id'], depth-1, bredth, last_author)

# %%
G = nx.DiGraph()
output_path = '%s_%d_%d.gexf'%(name.replace(' ','_'), depth, bredth)
build_graph(G, sch_id, depth, bredth)
nx.write_gexf(G, output_path)

# %%
from neo4j import (
    GraphDatabase,
)
from flask import (
    Flask,
    g,
    request,
    Response,
    send_from_directory
)

# %%
uri = "bolt://localhost:7687"  
username = "neo4j"
password = "zhiningbai"

driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
def get_db(database):
        # else:
        #     g.neo4j_db = driver.session()
    return driver.session(database=database)

# %%
def work(tx):
        return list(tx.run("""
            MATCH (n:Person)-[:IS_AUTHOR_OF]->(p)
            WHERE   labels(p) IN [['Publication'], ['Project'], ['Software']] AND
                    n.affiliation = "Netherlands eScience Center"
            RETURN  COLLECT(n.name) AS name_list, 
                    COLLECT(CASE WHEN (n.scopus_id) IS NOT NULL THEN n.scopus_id ELSE '' END) AS scopus_id, 
                    COLLECT(CASE WHEN (n.orcid) IS NOT NULL THEN n.orcid ELSE '' END) AS orcid,
                    COLLECT(CASE WHEN (n.affiliation) IS NOT NULL THEN n.affiliation ELSE '' END) AS affiliation,
                    COLLECT(CASE WHEN (n.country) IS NOT NULL THEN n.country ELSE '' END) AS country,
                    p.title AS title,
                    p.cited AS cited,
                    p.doi AS doi,
                    p.subject AS subject,
                    p.year AS year,
                    p.project_id AS project_id,
                    p.software_id AS software_id,
                    p.description AS description,
                    CASE 
                        WHEN labels(p) = ['Project'] THEN  'project'
                        WHEN labels(p) = ['Software'] THEN 'software'
                        WHEN labels(p) = ['Publication'] THEN 'publication'
                        ELSE '' 
                    END AS label
            """
        ))
db = get_db("rsd")
results = db.execute_read(work)

# %%
for record in results:
    for index in range(len(record["name_list"])):
        print(record['scopus_id'][index])
# Out:
# 57339115500
# 57222512827
# 57905129600
# 56493993600
# 6701436727
# 57904531300
# 57339115500
# 14029504000
# 57339115500
# 57222512827
# 56493993600
# 6701436727
# 57339115500
# 57339115500
# 57222512827
# 56493993600
# 57339115500
# 57222512827
# 56493993600
# 57339115500
# 57339115500
# 6701436727
# 57904531300
# 57339115500
# 56493993600
# 57339115500
# 57339115500
# 57222512827
# 26428846100
# 57905129600
# 56493993600
# 6701436727
# 57904531300
# 57339115500
# 24480411800
# 57222512827
# 26428846100
# 56493993600
# 6701436727
# 57904531300
# 57339115500
# 57222512827
# 26428846100
# 56493993600
# 57339115500
# 6701436727
# 15065185400
# 15065185400
# 15065185400
# 15065185400
# 15065185400
# 7006591871
# 6602305048
# 15065185400
# 15065185400
# 57220157018
# 55052390500
# 57807781300
# 55227059300
# 57189467443
# 55065848900
# 57189690259
# 57215841810
# 55171306200
# 57195348393
# 23096348600
# 57211407731
# 57807466500
# 15065185400
# 57215841810
# 57216997004
# 15065185400
# 7006591871
# 6602305048
# 15065185400
# 6602305048
# 15065185400
# 15065185400
# 55227059300
# 15065185400
# 6506427084
# 15065185400
# 7006591871
# 6602305048
# 15065185400
# 7006591871
# 6602305048
# 15065185400
# 7006591871
# 55052390500
# 6602305048
# 15065185400
# 7006591871
# 6506427084
# 55065848900
# 6602305048
# 15065185400
# 24480411800
# 57220157018
# 55065848900
# 14026072400
# 57189690259
# 55171306200
# 24173631200
# 57216997004
# 57610185400
# 15065185400
# 7006591871
# 6602305048
# 15065185400
# 8071168700
# 55065848900
# 6602660244
# 23096348600
# 15065185400
# 7006591871
# 6602660244
# 6602305048
# 15065185400
# 57215841810
# 15065185400
# 55065848900
# 15065185400
# 7006591871
# 6602660244
# 6602305048
# 15065185400
# 15065185400
# 7006591871
# 6602660244
# 6602305048
# 15065185400
# 8071168700
# 34880075200
# 23096348600
# 15065185400
# 23096348600
# 15065185400
# 6603590490
# 57220157018
# 57807781300
# 57189467443
# 57189690259
# 55934383800
# 57200435576
# 57215841810
# 55171306200
# 23096348600
# 57807466500
#
# 15065185400
# 7006591871
# 16052381000
# 55052390500
# 57190677035
# 55233782600
# 24490850400
# 55850186600
# 6602660244
# 23096348600
# 15065185400
# 55065848900
# 15065185400
# 6603590490
# 57807781300
# 6506427084
# 57189467443
# 57189690259
# 55934383800
# 57214165039
# 57215841810
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 24173631200
# 57904531300
# 57191484027
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195282624
# 57195348393
# 55392000700
# 55392000700
# 55392000700
# 57195348393
# 6602660244
# 56989634100
# 56989634100
# 56989634100
# 56989634100
# 56989634100
# 56989634100
# 56989634100
# 23096348600
# 23096348600
# 56533143200
# 23096348600
# 56533143200
# 23096348600
# 56533143200
# 23096348600
# 6507337066
# 23096348600
# 6507337066
# 56533143200
# 23096348600
# 6507337066
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 14034200400
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 23096348600
# 57216997004
# 57216997004
# 6507337066
# 6507337066
# 6507337066
# 6507337066
# 6507337066
# 6507337066
# 6507337066
#
# 56533143200
# 56533143200
# 56533143200
# 56533143200
# 56533143200
# 56533143200
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 39761504300
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 56232704500
# 57193025740
# 57193025740
# 57193025740

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def build_corpus(publications, num_topics, max_ngram_length=2):
    # Download necessary NLTK resources
    nltk.download('punkt')
    nltk.download('stopwords')
    nltk.download('wordnet')

    # Initialize tokenizer, stopwords, and lemmatizer
    tokenizer = nltk.RegexpTokenizer(r'\w+')
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()

    # Extract title and abstract from each publication
    documents = []
    for publication in publications:
        title = publication['title']
        if publication['description']:
            abstract = publication['description']
            documents.append(title + ' ' + abstract)
        else:
            documents.append(title)

    # Tokenize, remove stopwords, and lemmatize documents
    tokenized_documents = []
   
    for document in documents:
        tokens = tokenizer.tokenize(document.lower())
        filtered_tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
        tokenized_documents.append(' '.join(filtered_tokens))

    # Create TF-IDF matrix
    vectorizer = TfidfVectorizer(ngram_range=(1, max_ngram_length), min_df=5)
    tfidf_matrix = vectorizer.fit_transform(tokenized_documents)

    # Apply Latent Dirichlet Allocation (LDA) for topic modeling
    lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=42)
    lda_matrix = lda_model.fit_transform(tfidf_matrix)

    # Assign the group number to each publication
    groups = []
    topics = []
    for i, publication in enumerate(publications):
        groups.append(lda_matrix[i].argmax())
    for topic_idx, topic in enumerate(lda_model.components_):
        top_words_indices = topic.argsort()[:-11:-1]
        top_words = [vectorizer.get_feature_names_out()[index] for index in top_words_indices if topic[index] > 0.01]
        topics.append(top_words)
        
    return groups,topics

# %%
groups, topics = build_corpus(results, 15, 2)
# Out:
# [nltk_data] Downloading package punkt to /Users/jennifer/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jennifer/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jennifer/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
topics
# Out:
# [['cluster',
#   'multimedia',
#   'transparent',
#   'ion',
#   'star',
#   'benchmarking',
#   'mixed',
#   'survey',
#   'cation',
#   'parallel'],
#  ['galaxy',
#   'mass assembly',
#   'galaxy mass',
#   'assembly',
#   'mass',
#   'assembly gama',
#   'gama',
#   'verification',
#   'tracking',
#   'verification validation'],
#  ['sleep',
#   'accelerometer',
#   'hydrogen',
#   'physical activity',
#   'physical',
#   'excitation',
#   'activity',
#   'association',
#   'query',
#   'molecular'],
#  ['protein',
#   'neural network',
#   'neural',
#   'model',
#   'flow',
#   'network',
#   'transient',
#   'blood',
#   'high',
#   'wave'],
#  ['github',
#   'com',
#   'calibration',
#   'github com',
#   'gpu',
#   'optimization',
#   'http github',
#   'finite',
#   'motion',
#   'radio'],
#  ['diffraction',
#   'serial',
#   'interface',
#   'fair',
#   'electron',
#   'principle',
#   'passing',
#   'literature',
#   'food',
#   'temperature'],
#  ['dynamic',
#   'fast',
#   'family',
#   'column',
#   'molecular',
#   'logic',
#   'column store',
#   'molecular dynamic',
#   'store',
#   'architecture'],
#  ['mimetic',
#   'spectral',
#   'dot',
#   'element',
#   'quantum',
#   'dynamic',
#   'mimetic spectral',
#   'spectral element',
#   'quantum dot',
#   'square'],
#  ['data',
#   'tool',
#   'project',
#   'point',
#   'different',
#   'user',
#   'application',
#   'network',
#   'model',
#   'software'],
#  ['inf',
#   'inf inf',
#   'sup',
#   'molecule',
#   'knime',
#   'analysis',
#   'case',
#   'zeolite',
#   'energy surface',
#   'potential energy'],
#  ['interface',
#   'file',
#   'concept',
#   'run',
#   'data',
#   'python',
#   'kernel',
#   'question',
#   'code',
#   'ontology'],
#  ['simulation',
#   'model',
#   'climate',
#   'extreme',
#   'system',
#   'uncertainty',
#   'event',
#   'ct',
#   'black hole',
#   'multiscale'],
#  ['data',
#   'research',
#   'process',
#   'time',
#   'analysis',
#   'learning',
#   'project',
#   'software',
#   'based',
#   'aim'],
#  ['cosmic',
#   'cosmic web',
#   'temperature',
#   'knime',
#   'web',
#   'node',
#   'shape',
#   'container',
#   'text mining',
#   'north sea'],
#  ['tweet',
#   'equivalence',
#   'composition',
#   'building',
#   'automated',
#   'onto',
#   'disc',
#   'urban',
#   'measuring',
#   'complexity']]

# %%
topic_strings = []
for t in topics:
        topic_strings.append(t[0]+', '+t[1]+', '+t[2])
topic_strings
# Out:
# ['cluster, multimedia, transparent',
#  'galaxy, mass assembly, galaxy mass',
#  'sleep, accelerometer, hydrogen',
#  'protein, neural network, neural',
#  'github, com, calibration',
#  'diffraction, serial, interface',
#  'dynamic, fast, family',
#  'mimetic, spectral, dot',
#  'data, tool, project',
#  'inf, inf inf, sup',
#  'interface, file, concept',
#  'simulation, model, climate',
#  'data, research, process',
#  'cosmic, cosmic web, temperature',
#  'tweet, equivalence, composition']

# %%
groups
# Out:
# [12,
#  4,
#  8,
#  6,
#  8,
#  8,
#  4,
#  8,
#  10,
#  12,
#  12,
#  12,
#  12,
#  12,
#  8,
#  8,
#  13,
#  12,
#  0,
#  1,
#  4,
#  11,
#  12,
#  0,
#  14,
#  7,
#  11,
#  0,
#  10,
#  0,
#  10,
#  8,
#  10,
#  8,
#  8,
#  11,
#  3,
#  2,
#  12,
#  2,
#  8,
#  10,
#  10,
#  8,
#  8,
#  8,
#  8,
#  8,
#  3,
#  12,
#  8,
#  11,
#  11,
#  3,
#  12,
#  12,
#  8,
#  12,
#  8,
#  8,
#  8,
#  3,
#  11,
#  12,
#  8,
#  8,
#  11,
#  12,
#  8,
#  11,
#  8,
#  3,
#  11,
#  12,
#  12,
#  8,
#  8,
#  12,
#  8,
#  12,
#  1,
#  8,
#  12,
#  12,
#  12,
#  12,
#  8,
#  3,
#  11,
#  12,
#  8,
#  4,
#  8,
#  8,
#  12,
#  12,
#  9,
#  3,
#  9,
#  9,
#  9,
#  8,
#  8,
#  8,
#  12,
#  12,
#  8,
#  8,
#  8,
#  8,
#  2,
#  12,
#  8,
#  8,
#  14,
#  14,
#  8,
#  5,
#  6,
#  0,
#  8,
#  6,
#  8,
#  4,
#  11,
#  6,
#  1,
#  12,
#  5,
#  8,
#  12,
#  11,
#  2,
#  11,
#  8,
#  8,
#  12,
#  12,
#  12,
#  8,
#  11,
#  8,
#  8,
#  8,
#  12,
#  11,
#  12,
#  8,
#  8,
#  12,
#  12,
#  8,
#  11,
#  8,
#  12,
#  8,
#  8,
#  8,
#  8,
#  8,
#  12,
#  12,
#  8,
#  12,
#  11,
#  12,
#  12,
#  12,
#  10,
#  11,
#  10,
#  12,
#  8,
#  8,
#  8,
#  12,
#  8,
#  11,
#  10,
#  10,
#  12,
#  10,
#  8,
#  12,
#  12,
#  8,
#  12,
#  3,
#  12,
#  12,
#  12,
#  11,
#  7,
#  4,
#  8,
#  1,
#  4,
#  7,
#  6,
#  4,
#  7,
#  8,
#  12,
#  8,
#  11,
#  8,
#  12,
#  8,
#  12,
#  8,
#  8,
#  8,
#  12,
#  5,
#  5,
#  11,
#  11,
#  11,
#  10,
#  11,
#  6,
#  11,
#  11,
#  5,
#  6,
#  10,
#  3,
#  0,
#  10,
#  8,
#  3,
#  0,
#  8,
#  10,
#  12,
#  3,
#  8,
#  0,
#  8,
#  8,
#  8,
#  4,
#  10,
#  12,
#  2,
#  12,
#  3,
#  8,
#  8,
#  8,
#  8,
#  12,
#  8,
#  8,
#  8,
#  10,
#  12,
#  8,
#  12,
#  8,
#  12,
#  10,
#  8,
#  8,
#  12,
#  12,
#  10,
#  8,
#  8,
#  12,
#  12,
#  12,
#  8,
#  0,
#  12,
#  8,
#  8,
#  8,
#  3,
#  12,
#  8,
#  8,
#  8,
#  0,
#  8,
#  8,
#  10,
#  12,
#  8,
#  8,
#  12,
#  8,
#  12,
#  12,
#  3,
#  8,
#  8,
#  10,
#  12,
#  12,
#  11,
#  12,
#  8,
#  12,
#  8,
#  9,
#  13,
#  12,
#  1,
#  13,
#  9,
#  12,
#  8,
#  8,
#  8,
#  8,
#  12,
#  9,
#  8,
#  10,
#  5,
#  8,
#  0,
#  8,
#  10,
#  8,
#  9,
#  3,
#  1,
#  9,
#  9,
#  9,
#  9,
#  5,
#  5,
#  9,
#  5,
#  5,
#  1,
#  0,
#  5,
#  0,
#  5,
#  3,
#  12,
#  1,
#  9,
#  9,
#  5,
#  9,
#  5,
#  8,
#  8,
#  8,
#  10,
#  6,
#  11,
#  8,
#  14,
#  11,
#  9,
#  11,
#  11,
#  8,
#  11,
#  11,
#  8,
#  8,
#  10,
#  8,
#  8,
#  12,
#  12,
#  12,
#  8,
#  9,
#  8,
#  8,
#  8,
#  8,
#  2,
#  1,
#  12,
#  6,
#  9,
#  8,
#  6,
#  11,
#  8,
#  5,
#  4,
#  12,
#  8,
#  3,
#  1,
#  3,
#  3,
#  8,
#  8,
#  8,
#  8,
#  3,
#  8,
#  12,
#  12,
#  0,
#  13,
#  11,
#  12,
#  1,
#  13,
#  13,
#  8,
#  9,
#  10,
#  8,
#  8,
#  8,
#  8,
#  12,
#  8,
#  8,
#  2,
#  6,
#  6,
#  9,
#  9,
#  12,
#  12,
#  6,
#  9,
#  6,
#  6,
#  8,
#  1,
#  12,
#  6,
#  2,
#  6,
#  8,
#  11,
#  8,
#  12,
#  8,
#  10,
#  14,
#  8,
#  10,
#  0,
#  14,
#  4,
#  6,
#  10,
#  10,
#  12,
#  8,
#  10,
#  8,
#  6,
#  8,
#  11,
#  12,
#  12,
#  6,
#  2,
#  7,
#  7,
#  3,
#  13,
#  6,
#  6,
#  4,
#  9,
#  4,
#  12,
#  0,
#  8,
#  3,
#  12,
#  11,
#  12,
#  5,
#  8,
#  3,
#  3,
#  12,
#  8,
#  8,
#  0,
#  11,
#  6,
#  1,
#  9,
#  11,
#  9,
#  9,
#  8,
#  1,
#  3,
#  9,
#  0,
#  12,
#  12,
#  12,
#  12,
#  8,
#  8,
#  12,
#  12,
#  8,
#  12,
#  8,
#  8,
#  8,
#  12,
#  8,
#  12,
#  8,
#  12,
#  8,
#  12,
#  12,
#  3,
#  12,
#  8,
#  8,
#  12,
#  8,
#  8,
#  8,
#  12,
#  8,
#  8,
#  4,
#  6,
#  1,
#  0,
#  6,
#  11,
#  3,
#  6,
#  8,
#  12,
#  11,
#  6,
#  8,
#  11,
#  11,
#  7,
#  7,
#  3,
#  0,
#  11,
#  8,
#  3,
#  11,
#  11,
#  11,
#  12,
#  12,
#  3,
#  3,
#  12,
#  12,
#  8,
#  8,
#  12,
#  8,
#  8,
#  8,
#  6,
#  9,
#  7,
#  8,
#  1,
#  0,
#  1,
#  1,
#  12,
#  13,
#  1,
#  1,
#  1,
#  8,
#  0,
#  8,
#  1,
#  0,
#  1,
#  7,
#  4,
#  1,
#  1,
#  8,
#  10,
#  6,
#  8,
#  14,
#  9,
#  8,
#  2,
#  0,
#  4,
#  13,
#  11,
#  11,
#  8,
#  8,
#  3,
#  1,
#  11,
#  3,
#  10,
#  6,
#  11,
#  13,
#  6,
#  3,
#  9,
#  0,
#  7,
#  2,
#  7,
#  9,
#  8,
#  6,
#  9,
#  11,
#  7,
#  12,
#  12,
#  3,
#  8,
#  8,
#  8,
#  8,
#  4,
#  8,
#  12,
#  11,
#  8,
#  12,
#  3,
#  13,
#  3,
#  5,
#  7,
#  4,
#  4,
#  4,
#  10,
#  5,
#  2,
#  4,
#  4,
#  14,
#  4,
#  10,
#  8,
#  10,
#  10,
#  4,
#  10,
#  10,
#  8,
#  12,
#  9,
#  11,
#  6,
#  10,
#  13,
#  8,
#  12,
#  8,
#  6,
#  8,
#  8,
#  12,
#  12,
#  8,
#  4,
#  3,
#  13,
#  6,
#  7,
#  12,
#  2,
#  6,
#  7,
#  6,
#  3,
#  3,
#  9,
#  8,
#  3,
#  3,
#  3,
#  8,
#  3,
#  3,
#  3,
#  8,
#  8,
#  8,
#  13,
#  11,
#  13,
#  3,
#  9,
#  8,
#  0,
#  8,
#  12,
#  9,
#  8,
#  11,
#  14,
#  14,
#  8,
#  8,
#  8,
#  8,
#  6,
#  5,
#  9,
#  8,
#  11,
#  12,
#  8,
#  8,
#  14,
#  5,
#  7,
#  8,
#  10,
#  5,
#  12,
#  7,
#  3,
#  5,
#  8,
#  8,
#  3,
#  12,
#  8,
#  8,
#  8,
#  0,
#  3,
#  1,
#  3,
#  0,
#  11,
#  8,
#  12,
#  14,
#  11,
#  8,
#  9,
#  7,
#  14,
#  12,
#  12,
#  12,
#  11,
#  14,
#  11,
#  12,
#  0,
#  8,
#  12,
#  8,
#  4,
#  10,
#  8,
#  8,
#  0,
#  7,
#  8,
#  7,
#  8,
#  11,
#  3,
#  1,
#  14,
#  10,
#  8,
#  4,
#  10,
#  10,
#  8,
#  11,
#  4,
#  1,
#  3,
#  3,
#  7,
#  11,
#  13,
#  3,
#  4,
#  11,
#  1,
#  14,
#  3,
#  11,
#  11,
#  7,
#  11,
#  3,
#  11,
#  4,
#  8,
#  2,
#  2,
#  5,
#  10,
#  12,
#  10,
#  14,
#  5,
#  2,
#  12,
#  14,
#  12,
#  2,
#  7,
#  6,
#  6,
#  2,
#  2,
#  2,
#  8,
#  14,
#  2,
#  8,
#  8,
#  11,
#  11,
#  1,
#  12,
#  11,
#  1,
#  10,
#  8,
#  12,
#  9,
#  3,
#  6,
#  11,
#  8,
#  12,
#  14,
#  12,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  4,
#  13,
#  11,
#  14,
#  10,
#  6,
#  3,
#  13,
#  3,
#  13,
#  13,
#  12,
#  12,
#  8,
#  8,
#  1,
#  13,
#  8,
#  8,
#  5,
#  9,
#  4,
#  9,
#  14,
#  8,
#  5,
#  5,
#  14,
#  5,
#  5,
#  5,
#  5,
#  8,
#  8,
#  12,
#  7,
#  1,
#  12,
#  1,
#  1,
#  12,
#  0,
#  7,
#  0,
#  0,
#  12,
#  8,
#  2,
#  0,
#  4,
#  8,
#  5,
#  8,
#  8,
#  8,
#  8,
#  5,
#  5,
#  14,
#  5,
#  10,
#  1,
#  13,
#  9,
#  13,
#  9,
#  6,
#  11,
#  6,
#  8,
#  9,
#  11,
#  9,
#  11,
#  6,
#  9,
#  10,
#  6,
#  12,
#  11,
#  10,
#  14,
#  10,
#  12,
#  2,
#  13,
#  14,
#  14,
#  8,
#  8,
#  8,
#  4,
#  10,
#  8,
#  8,
#  8,
#  12,
#  12,
#  9,
#  12,
#  8,
#  9,
#  4,
#  0,
#  8,
#  12,
#  12,
#  6,
#  6,
#  4,
#  7,
#  12,
#  4,
#  0,
#  13,
#  9,
#  12,
#  8,
#  5,
#  6,
#  4,
#  5,
#  2,
#  10,
#  2,
#  1,
#  6,
#  4,
#  5,
#  3,
#  5,
#  1,
#  6,
#  1,
#  9,
#  10,
#  8,
#  14,
#  8,
#  1,
#  ...]
