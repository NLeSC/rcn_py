# %% [markdown]
# ## Functions for CrossRef (ORCID) data

# %%
import sys
sys.path.append("..")
from rcn_py import orcid
from rcn_py import topic_modeling

# %% [markdown]
# `name_to_orcid_id(name)`
#
# This function queries the ORCID API using a full name and returns the corresponding ORCID ID if found. It performs the following steps:
#
# - Constructs the necessary headers and parameters for the API request.
# - Sends a GET request to the ORCID API to search for the name.
# - Extracts the ORCID ID from the response if any results are found.
# - Returns the ORCID ID or None if not found.

# %%
# query ORCID by a fullname
orcid_id = orcid.name_to_orcid_id('Peter Kalverla')
orcid_id
# Out:
# '0000-0002-5025-7862'

# %% [markdown]
# `from_orcid_to_name(orcid_id)`
#
# This function queries ORCID for a specific ORCID ID and retrieves the corresponding author's name. It performs the following steps:
#
# - Queries the ORCID API for the record associated with the provided ORCID ID using the query_orcid_for_record function.
# - Extracts the author's name from the ORCID record.
# - Returns the author's name.

# %%
fullname = orcid.from_orcid_to_name(orcid_id)
fullname
# Out:
# 'Peter Kalverla'

# %% [markdown]
# `query_orcid_for_record(orcid_id)`
#
# This function queries the ORCID API for a specific ORCID ID and retrieves the associated record. It performs the following steps:
#
# - Sends a GET request to the ORCID API with the provided ORCID ID.
# - Retrieves the JSON data from the response if the request is successful.
# - Returns the JSON data as a Python dictionary or False if the request is not successful.

# %%
# query ORCID for an ORCID record
orcid_record = orcid.query_orcid_for_record(orcid_id)
orcid_record
# Out:
# {'orcid-identifier': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#   'path': '0000-0002-5025-7862',
#   'host': 'orcid.org'},
#  'preferences': {'locale': 'en'},
#  'history': {'creation-method': 'DIRECT',
#   'completion-date': None,
#   'submission-date': {'value': 1440847595525},
#   'last-modified-date': {'value': 1677858209460},
#   'claimed': True,
#   'source': None,
#   'deactivation-date': None,
#   'verified-email': True,
#   'verified-primary-email': True},
#  'person': {'last-modified-date': {'value': 1614867500639},
#   'name': {'created-date': {'value': 1460759791637},
#    'last-modified-date': {'value': 1460759791637},
#    'given-names': {'value': 'Peter'},
#    'family-name': {'value': 'Kalverla'},
#    'credit-name': None,
#    'source': None,
#    'visibility': 'public',
#    'path': '0000-0002-5025-7862'},
#   'other-names': {'last-modified-date': None,
#    'other-name': [],
#    'path': '/0000-0002-5025-7862/other-names'},
#   'biography': None,
#   'researcher-urls': {'last-modified-date': None,
#    'researcher-url': [],
#    'path': '/0000-0002-5025-7862/researcher-urls'},
#   'emails': {'last-modified-date': None,
#    'email': [],
#    'path': '/0000-0002-5025-7862/email'},
#   'addresses': {'last-modified-date': {'value': 1465226976952},
#    'address': [{'created-date': {'value': 1453659122071},
#      'last-modified-date': {'value': 1465226976952},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#        'path': '0000-0002-5025-7862',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Peter Kalverla'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'country': {'value': 'NL'},
#      'visibility': 'public',
#      'path': '/0000-0002-5025-7862/address/102389',
#      'put-code': 102389,
#      'display-index': 0}],
#    'path': '/0000-0002-5025-7862/address'},
#   'keywords': {'last-modified-date': {'value': 1614867500639},
#    'keyword': [{'created-date': {'value': 1614867500634},
#      'last-modified-date': {'value': 1614867500634},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#        'path': '0000-0002-5025-7862',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Peter Kalverla'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'content': 'Reproducible science',
#      'visibility': 'public',
#      'path': '/0000-0002-5025-7862/keywords/1877126',
#      'put-code': 1877126,
#      'display-index': 4},
#     {'created-date': {'value': 1614867500637},
#      'last-modified-date': {'value': 1614867500637},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#        'path': '0000-0002-5025-7862',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Peter Kalverla'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'content': 'Research software engineering',
#      'visibility': 'public',
#      'path': '/0000-0002-5025-7862/keywords/1877127',
#      'put-code': 1877127,
#      'display-index': 3},
#     {'created-date': {'value': 1614867500638},
#      'last-modified-date': {'value': 1614867500638},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#        'path': '0000-0002-5025-7862',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Peter Kalverla'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'content': 'Meteorology',
#      'visibility': 'public',
#      'path': '/0000-0002-5025-7862/keywords/1877128',
#      'put-code': 1877128,
#      'display-index': 2},
#     {'created-date': {'value': 1614867500639},
#      'last-modified-date': {'value': 1614867500639},
#      'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#        'path': '0000-0002-5025-7862',
#        'host': 'orcid.org'},
#       'source-client-id': None,
#       'source-name': {'value': 'Peter Kalverla'},
#       'assertion-origin-orcid': None,
#       'assertion-origin-client-id': None,
#       'assertion-origin-name': None},
#      'content': 'Wind Energy',
#      'visibility': 'public',
#      'path': '/0000-0002-5025-7862/keywords/1877129',
#      'put-code': 1877129,
#      'display-index': 1}],
#    'path': '/0000-0002-5025-7862/keywords'},
#   'external-identifiers': {'last-modified-date': None,
#    'external-identifier': [],
#    'path': '/0000-0002-5025-7862/external-identifiers'},
#   'path': '/0000-0002-5025-7862/person'},
#  'activities-summary': {'last-modified-date': {'value': 1654040356185},
#   'distinctions': {'last-modified-date': None,
#    'affiliation-group': [],
#    'path': '/0000-0002-5025-7862/distinctions'},
#   'educations': {'last-modified-date': None,
#    'affiliation-group': [],
#    'path': '/0000-0002-5025-7862/educations'},
#   'employments': {'last-modified-date': {'value': 1614867265605},
#    'affiliation-group': [{'last-modified-date': {'value': 1614867265605},
#      'external-ids': {'external-id': []},
#      'summaries': [{'employment-summary': {'created-date': {'value': 1579080783039},
#         'last-modified-date': {'value': 1614867265605},
#         'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#           'path': '0000-0002-5025-7862',
#           'host': 'orcid.org'},
#          'source-client-id': None,
#          'source-name': {'value': 'Peter Kalverla'},
#          'assertion-origin-orcid': None,
#          'assertion-origin-client-id': None,
#          'assertion-origin-name': None},
#         'put-code': 9557318,
#         'department-name': None,
#         'role-title': 'Research Software Engineer',
#         'start-date': {'year': {'value': '2019'},
#          'month': {'value': '09'},
#          'day': {'value': '16'}},
#         'end-date': None,
#         'organization': {'name': 'Netherlands eScience Center',
#          'address': {'city': 'Amsterdam', 'region': None, 'country': 'NL'},
#          'disambiguated-organization': None},
#         'url': None,
#         'external-ids': None,
#         'display-index': '1',
#         'visibility': 'public',
#         'path': '/0000-0002-5025-7862/employment/9557318'}}]}],
#    'path': '/0000-0002-5025-7862/employments'},
#   'fundings': {'last-modified-date': None,
#    'group': [],
#    'path': '/0000-0002-5025-7862/fundings'},
#   'invited-positions': {'last-modified-date': None,
#    'affiliation-group': [],
#    'path': '/0000-0002-5025-7862/invited-positions'},
#   'memberships': {'last-modified-date': None,
#    'affiliation-group': [],
#    'path': '/0000-0002-5025-7862/memberships'},
#   'peer-reviews': {'last-modified-date': None,
#    'group': [],
#    'path': '/0000-0002-5025-7862/peer-reviews'},
#   'qualifications': {'last-modified-date': None,
#    'affiliation-group': [],
#    'path': '/0000-0002-5025-7862/qualifications'},
#   'research-resources': {'last-modified-date': None,
#    'group': [],
#    'path': '/0000-0002-5025-7862/research-resources'},
#   'services': {'last-modified-date': None,
#    'affiliation-group': [],
#    'path': '/0000-0002-5025-7862/services'},
#   'works': {'last-modified-date': {'value': 1654040356185},
#    'group': [{'last-modified-date': {'value': 1654040356185},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu21-9387',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu21-9387',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-9387'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89903286,
#        'created-date': {'value': 1614838570891},
#        'last-modified-date': {'value': 1654040356185},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'A multi-model ensemble weighting method (ClimWIP) in ESMValTool'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu21-9387',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu21-9387',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-9387'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-9387'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2021'},
#         'month': {'value': '03'},
#         'day': {'value': '04'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89903286',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1654040311968},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu21-6051',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu21-6051',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-6051'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89895438,
#        'created-date': {'value': 1614828761075},
#        'last-modified-date': {'value': 1654040311968},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Preprocessing of hydrological models&#8217; input in eWaterCycle with ESMValTool'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu21-6051',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu21-6051',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-6051'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-6051'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2021'},
#         'month': {'value': '03'},
#         'day': {'value': '04'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89895438',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1654040328473},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu21-7797',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu21-7797',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-7797'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89897996,
#        'created-date': {'value': 1614831788306},
#        'last-modified-date': {'value': 1654040328473},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Towards Open and FAIR Hydrological Modelling with eWaterCycle'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu21-7797',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu21-7797',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-7797'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-7797'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2021'},
#         'month': {'value': '03'},
#         'day': {'value': '04'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89897996',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1654040272563},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu21-4805',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu21-4805',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4805'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89889090,
#        'created-date': {'value': 1614819736472},
#        'last-modified-date': {'value': 1654040272563},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Bringing ESMValTool to the Jupyter Lab'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu21-4805',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu21-4805',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4805'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4805'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2021'},
#         'month': {'value': '03'},
#         'day': {'value': '03'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89889090',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1654040221744},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu21-3476',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu21-3476',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-3476'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89881679,
#        'created-date': {'value': 1614810069897},
#        'last-modified-date': {'value': 1654040221744},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Recent developments on the Earth System Model Evaluation Tool'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu21-3476',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu21-3476',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-3476'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-3476'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2021'},
#         'month': {'value': '03'},
#         'day': {'value': '03'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89881679',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1654040272575},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu21-4895',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu21-4895',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4895'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89889092,
#        'created-date': {'value': 1614819737006},
#        'last-modified-date': {'value': 1654040272575},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'era5cli: the command line interface to ERA5 data'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu21-4895',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu21-4895',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4895'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4895'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2021'},
#         'month': {'value': '03'},
#         'day': {'value': '03'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89889092',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1653955301966},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/wes-5-1097-2020',
#         'external-id-normalized': {'value': '10.5194/wes-5-1097-2020',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/wes-5-1097-2020'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 79257344,
#        'created-date': {'value': 1598260071587},
#        'last-modified-date': {'value': 1653955301966},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Clustering wind profile shapes to estimate airborne wind energy production'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/wes-5-1097-2020',
#           'external-id-normalized': {'value': '10.5194/wes-5-1097-2020',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/wes-5-1097-2020'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/wes-5-1097-2020'},
#        'type': 'journal-article',
#        'publication-date': {'year': {'value': '2020'},
#         'month': {'value': '08'},
#         'day': {'value': '24'}},
#        'journal-title': {'value': 'Wind Energy Science'},
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/79257344',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1653871543831},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/egusphere-egu2020-21619',
#         'external-id-normalized': {'value': '10.5194/egusphere-egu2020-21619',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu2020-21619'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 70347138,
#        'created-date': {'value': 1583824489633},
#        'last-modified-date': {'value': 1653871543831},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'era5cli: The command line tool to download ERA5 data'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/egusphere-egu2020-21619',
#           'external-id-normalized': {'value': '10.5194/egusphere-egu2020-21619',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu2020-21619'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/egusphere-egu2020-21619'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2020'},
#         'month': {'value': '03'},
#         'day': {'value': '23'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/70347138',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1614868747888},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.18174/498797',
#         'external-id-normalized': {'value': '10.18174/498797',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.18174/498797'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 89943809,
#        'created-date': {'value': 1614868747888},
#        'last-modified-date': {'value': 1614868747888},
#        'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#          'path': '0000-0002-5025-7862',
#          'host': 'orcid.org'},
#         'source-client-id': None,
#         'source-name': {'value': 'Peter Kalverla'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Characterisation of offshore winds for energy applications'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.18174/498797',
#           'external-id-normalized': {'value': '10.18174/498797',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.18174/498797'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://wur.on.worldcat.org/oclc/1127050287'},
#        'type': 'dissertation-thesis',
#        'publication-date': {'year': {'value': '2019'},
#         'month': {'value': '11'},
#         'day': {'value': '13'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/89943809',
#        'display-index': '1'}]},
#     {'last-modified-date': {'value': 1653697306883},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/wes-4-193-2019',
#         'external-id-normalized': {'value': '10.5194/wes-4-193-2019',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/wes-4-193-2019'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 56051688,
#        'created-date': {'value': 1554295213237},
#        'last-modified-date': {'value': 1653697306883},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Low-level jets over the North Sea based on ERA5 and observations: together they do better'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/wes-4-193-2019',
#           'external-id-normalized': {'value': '10.5194/wes-4-193-2019',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/wes-4-193-2019'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/wes-4-193-2019'},
#        'type': 'journal-article',
#        'publication-date': {'year': {'value': '2019'},
#         'month': {'value': '04'},
#         'day': {'value': '03'}},
#        'journal-title': {'value': 'Wind Energy Science'},
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/56051688',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1653801178444},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.5194/wes-2018-79-supplement',
#         'external-id-normalized': {'value': '10.5194/wes-2018-79-supplement',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.5194/wes-2018-79-supplement'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 63603267,
#        'created-date': {'value': 1571944377143},
#        'last-modified-date': {'value': 1653801178444},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Supplementary material to &quot;Low-level jets over the North Sea based on ERA5 and observations: together they do better&quot;'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.5194/wes-2018-79-supplement',
#           'external-id-normalized': {'value': '10.5194/wes-2018-79-supplement',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.5194/wes-2018-79-supplement'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.5194/wes-2018-79-supplement'},
#        'type': 'other',
#        'publication-date': {'year': {'value': '2019'},
#         'month': {'value': '01'},
#         'day': {'value': '08'}},
#        'journal-title': None,
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/63603267',
#        'display-index': '0'}]},
#     {'last-modified-date': {'value': 1653647742901},
#      'external-ids': {'external-id': [{'external-id-type': 'doi',
#         'external-id-value': '10.1002/we.2267',
#         'external-id-normalized': {'value': '10.1002/we.2267',
#          'transient': True},
#         'external-id-normalized-error': None,
#         'external-id-url': {'value': 'https://doi.org/10.1002/we.2267'},
#         'external-id-relationship': 'self'}]},
#      'work-summary': [{'put-code': 50296078,
#        'created-date': {'value': 1541577799028},
#        'last-modified-date': {'value': 1653647742901},
#        'source': {'source-orcid': None,
#         'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#          'path': '0000-0001-9884-1913',
#          'host': 'orcid.org'},
#         'source-name': {'value': 'Crossref'},
#         'assertion-origin-orcid': None,
#         'assertion-origin-client-id': None,
#         'assertion-origin-name': None},
#        'title': {'title': {'value': 'Evaluation of three mainstream numerical weather prediction models with observations from meteorological mast IJmuiden at the North Sea'},
#         'subtitle': None,
#         'translated-title': None},
#        'external-ids': {'external-id': [{'external-id-type': 'doi',
#           'external-id-value': '10.1002/we.2267',
#           'external-id-normalized': {'value': '10.1002/we.2267',
#            'transient': True},
#           'external-id-normalized-error': None,
#           'external-id-url': {'value': 'https://doi.org/10.1002/we.2267'},
#           'external-id-relationship': 'self'}]},
#        'url': {'value': 'https://doi.org/10.1002/we.2267'},
#        'type': 'journal-article',
#        'publication-date': {'year': {'value': '2019'},
#         'month': {'value': '01'},
#         'day': {'value': '07'}},
#        'journal-title': {'value': 'Wind Energy'},
#        'visibility': 'public',
#        'path': '/0000-0002-5025-7862/work/50296078',
#        'display-index': '0'}]}],
#    'path': '/0000-0002-5025-7862/works'},
#   'path': '/0000-0002-5025-7862/activities'},
#  'path': '/0000-0002-5025-7862'}

# %% [markdown]
# `extract_works_section(orcid_record)`
#
# This function extracts the "works" section from an ORCID record. It performs the following steps:
#
# - Retrieves the "works" section from the provided ORCID record.
# - Returns the "works" section.

# %%
docs = orcid.extract_works_section(orcid_record)
docs
# Out:
# [{'last-modified-date': {'value': 1654040356185},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu21-9387',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu21-9387',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-9387'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89903286,
#     'created-date': {'value': 1614838570891},
#     'last-modified-date': {'value': 1654040356185},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'A multi-model ensemble weighting method (ClimWIP) in ESMValTool'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu21-9387',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu21-9387',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-9387'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-9387'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2021'},
#      'month': {'value': '03'},
#      'day': {'value': '04'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89903286',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1654040311968},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu21-6051',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu21-6051',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-6051'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89895438,
#     'created-date': {'value': 1614828761075},
#     'last-modified-date': {'value': 1654040311968},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Preprocessing of hydrological models&#8217; input in eWaterCycle with ESMValTool'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu21-6051',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu21-6051',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-6051'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-6051'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2021'},
#      'month': {'value': '03'},
#      'day': {'value': '04'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89895438',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1654040328473},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu21-7797',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu21-7797',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-7797'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89897996,
#     'created-date': {'value': 1614831788306},
#     'last-modified-date': {'value': 1654040328473},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Towards Open and FAIR Hydrological Modelling with eWaterCycle'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu21-7797',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu21-7797',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-7797'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-7797'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2021'},
#      'month': {'value': '03'},
#      'day': {'value': '04'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89897996',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1654040272563},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu21-4805',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu21-4805',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4805'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89889090,
#     'created-date': {'value': 1614819736472},
#     'last-modified-date': {'value': 1654040272563},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Bringing ESMValTool to the Jupyter Lab'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu21-4805',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu21-4805',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4805'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4805'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2021'},
#      'month': {'value': '03'},
#      'day': {'value': '03'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89889090',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1654040221744},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu21-3476',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu21-3476',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-3476'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89881679,
#     'created-date': {'value': 1614810069897},
#     'last-modified-date': {'value': 1654040221744},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Recent developments on the Earth System Model Evaluation Tool'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu21-3476',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu21-3476',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-3476'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-3476'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2021'},
#      'month': {'value': '03'},
#      'day': {'value': '03'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89881679',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1654040272575},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu21-4895',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu21-4895',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4895'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89889092,
#     'created-date': {'value': 1614819737006},
#     'last-modified-date': {'value': 1654040272575},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'era5cli: the command line interface to ERA5 data'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu21-4895',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu21-4895',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4895'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu21-4895'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2021'},
#      'month': {'value': '03'},
#      'day': {'value': '03'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89889092',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1653955301966},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/wes-5-1097-2020',
#      'external-id-normalized': {'value': '10.5194/wes-5-1097-2020',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/wes-5-1097-2020'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 79257344,
#     'created-date': {'value': 1598260071587},
#     'last-modified-date': {'value': 1653955301966},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Clustering wind profile shapes to estimate airborne wind energy production'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/wes-5-1097-2020',
#        'external-id-normalized': {'value': '10.5194/wes-5-1097-2020',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/wes-5-1097-2020'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/wes-5-1097-2020'},
#     'type': 'journal-article',
#     'publication-date': {'year': {'value': '2020'},
#      'month': {'value': '08'},
#      'day': {'value': '24'}},
#     'journal-title': {'value': 'Wind Energy Science'},
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/79257344',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1653871543831},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/egusphere-egu2020-21619',
#      'external-id-normalized': {'value': '10.5194/egusphere-egu2020-21619',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu2020-21619'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 70347138,
#     'created-date': {'value': 1583824489633},
#     'last-modified-date': {'value': 1653871543831},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'era5cli: The command line tool to download ERA5 data'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/egusphere-egu2020-21619',
#        'external-id-normalized': {'value': '10.5194/egusphere-egu2020-21619',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/egusphere-egu2020-21619'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/egusphere-egu2020-21619'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2020'},
#      'month': {'value': '03'},
#      'day': {'value': '23'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/70347138',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1614868747888},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.18174/498797',
#      'external-id-normalized': {'value': '10.18174/498797', 'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.18174/498797'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 89943809,
#     'created-date': {'value': 1614868747888},
#     'last-modified-date': {'value': 1614868747888},
#     'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-5025-7862',
#       'path': '0000-0002-5025-7862',
#       'host': 'orcid.org'},
#      'source-client-id': None,
#      'source-name': {'value': 'Peter Kalverla'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Characterisation of offshore winds for energy applications'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.18174/498797',
#        'external-id-normalized': {'value': '10.18174/498797',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.18174/498797'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://wur.on.worldcat.org/oclc/1127050287'},
#     'type': 'dissertation-thesis',
#     'publication-date': {'year': {'value': '2019'},
#      'month': {'value': '11'},
#      'day': {'value': '13'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/89943809',
#     'display-index': '1'}]},
#  {'last-modified-date': {'value': 1653697306883},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/wes-4-193-2019',
#      'external-id-normalized': {'value': '10.5194/wes-4-193-2019',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/wes-4-193-2019'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 56051688,
#     'created-date': {'value': 1554295213237},
#     'last-modified-date': {'value': 1653697306883},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Low-level jets over the North Sea based on ERA5 and observations: together they do better'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/wes-4-193-2019',
#        'external-id-normalized': {'value': '10.5194/wes-4-193-2019',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/wes-4-193-2019'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/wes-4-193-2019'},
#     'type': 'journal-article',
#     'publication-date': {'year': {'value': '2019'},
#      'month': {'value': '04'},
#      'day': {'value': '03'}},
#     'journal-title': {'value': 'Wind Energy Science'},
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/56051688',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1653801178444},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.5194/wes-2018-79-supplement',
#      'external-id-normalized': {'value': '10.5194/wes-2018-79-supplement',
#       'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.5194/wes-2018-79-supplement'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 63603267,
#     'created-date': {'value': 1571944377143},
#     'last-modified-date': {'value': 1653801178444},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Supplementary material to &quot;Low-level jets over the North Sea based on ERA5 and observations: together they do better&quot;'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.5194/wes-2018-79-supplement',
#        'external-id-normalized': {'value': '10.5194/wes-2018-79-supplement',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.5194/wes-2018-79-supplement'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.5194/wes-2018-79-supplement'},
#     'type': 'other',
#     'publication-date': {'year': {'value': '2019'},
#      'month': {'value': '01'},
#      'day': {'value': '08'}},
#     'journal-title': None,
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/63603267',
#     'display-index': '0'}]},
#  {'last-modified-date': {'value': 1653647742901},
#   'external-ids': {'external-id': [{'external-id-type': 'doi',
#      'external-id-value': '10.1002/we.2267',
#      'external-id-normalized': {'value': '10.1002/we.2267', 'transient': True},
#      'external-id-normalized-error': None,
#      'external-id-url': {'value': 'https://doi.org/10.1002/we.2267'},
#      'external-id-relationship': 'self'}]},
#   'work-summary': [{'put-code': 50296078,
#     'created-date': {'value': 1541577799028},
#     'last-modified-date': {'value': 1653647742901},
#     'source': {'source-orcid': None,
#      'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913',
#       'path': '0000-0001-9884-1913',
#       'host': 'orcid.org'},
#      'source-name': {'value': 'Crossref'},
#      'assertion-origin-orcid': None,
#      'assertion-origin-client-id': None,
#      'assertion-origin-name': None},
#     'title': {'title': {'value': 'Evaluation of three mainstream numerical weather prediction models with observations from meteorological mast IJmuiden at the North Sea'},
#      'subtitle': None,
#      'translated-title': None},
#     'external-ids': {'external-id': [{'external-id-type': 'doi',
#        'external-id-value': '10.1002/we.2267',
#        'external-id-normalized': {'value': '10.1002/we.2267',
#         'transient': True},
#        'external-id-normalized-error': None,
#        'external-id-url': {'value': 'https://doi.org/10.1002/we.2267'},
#        'external-id-relationship': 'self'}]},
#     'url': {'value': 'https://doi.org/10.1002/we.2267'},
#     'type': 'journal-article',
#     'publication-date': {'year': {'value': '2019'},
#      'month': {'value': '01'},
#      'day': {'value': '07'}},
#     'journal-title': {'value': 'Wind Energy'},
#     'visibility': 'public',
#     'path': '/0000-0002-5025-7862/work/50296078',
#     'display-index': '0'}]}]

# %% [markdown]
# `extract_doi(work)`
#
# This function extracts the title and DOI(s) from a work object. It performs the following steps:
#
# - Extracts the title from the work object.
# - Extracts the DOI(s) from the work object.
# - Returns the DOI(s) and the title.

# %%
# extract title and DOI
doi_list = []
title_list = []
for i in docs:
    doi, title = orcid.extract_doi(i)
    doi_list.append(doi)
    title_list.append(title)
print(doi_list)
print(title_list)
# Out:
# ['10.5194/egusphere-egu21-9387', '10.5194/egusphere-egu21-6051', '10.5194/egusphere-egu21-7797', '10.5194/egusphere-egu21-4805', '10.5194/egusphere-egu21-3476', '10.5194/egusphere-egu21-4895', '10.5194/wes-5-1097-2020', '10.5194/egusphere-egu2020-21619', '10.18174/498797', '10.5194/wes-4-193-2019', '10.5194/wes-2018-79-supplement', '10.1002/we.2267']
# ['A multi-model ensemble weighting method (ClimWIP) in ESMValTool', 'Preprocessing of hydrological models&#8217; input in eWaterCycle with ESMValTool', 'Towards Open and FAIR Hydrological Modelling with eWaterCycle', 'Bringing ESMValTool to the Jupyter Lab', 'Recent developments on the Earth System Model Evaluation Tool', 'era5cli: the command line interface to ERA5 data', 'Clustering wind profile shapes to estimate airborne wind energy production', 'era5cli: The command line tool to download ERA5 data', 'Characterisation of offshore winds for energy applications', 'Low-level jets over the North Sea based on ERA5 and observations: together they do better', 'Supplementary material to &quot;Low-level jets over the North Sea based on ERA5 and observations: together they do better&quot;', 'Evaluation of three mainstream numerical weather prediction models with observations from meteorological mast IJmuiden at the North Sea']

# %% [markdown]
# `orcid_lda_cluster(dois)`
#
# This function applies LDA topic modeling and clustering to a list of DOIs. It performs the following steps:
#
# - Preprocesses the abstracts associated with the DOIs.
# - Creates a dictionary and corpus for the LDA model.
# - Applies LDA topic modeling using the gensim library.
# - Assigns clusters based on topic scores.
# - Returns a dictionary mapping DOIs to cluster assignments and a dictionary mapping cluster indices to topics.

# %%
clusters = orcid.orcid_lda_cluster(doi_list)
clusters
# Out:
# {'10.5194/egusphere-egu21-9387': 0,
#  '10.5194/egusphere-egu21-6051': 0,
#  '10.5194/egusphere-egu21-7797': 0,
#  '10.5194/egusphere-egu21-4805': 0,
#  '10.5194/egusphere-egu21-3476': 0,
#  '10.5194/egusphere-egu21-4895': 0,
#  '10.5194/wes-5-1097-2020': 0,
#  '10.5194/egusphere-egu2020-21619': 0,
#  '10.18174/498797': 5,
#  '10.5194/wes-4-193-2019': 0,
#  '10.5194/wes-2018-79-supplement': 2,
#  '10.1002/we.2267': 0}

# %% [markdown]
# `orcid_get_coauthors(full_name)`
#
# This function retrieves co-author information for a given full name using ORCID data. It performs the following steps:
#
# - Retrieves the ORCID ID for the given full name using the name_to_orcid_id function.
# - Queries the ORCID API for the author's record using the ORCID ID.
# - Extracts the "works" section from the ORCID record.
# - Performs LDA topic modeling on the DOIs extracted from the "works" section.
# - Filters authors based on certain criteria such as country.
# - Generates co-author links and stores co-author information.
# - Assigns new group numbers based on unique groups.
# - Returns a DataFrame containing co-author information and a list of co-author links.

# %%
df, links = orcid.orcid_get_coauthors('Peter Kalverla')

# %%
df
# Out:
#                   orcid                    name  group
# 0   0000-0002-3986-1268             Ruth Lorenz      0
# 1   0000-0001-5760-4524           Lukas Brunner      0
# 2   0000-0002-5025-7862          Peter Kalverla      0
# 3   0000-0002-5413-9038             Stef Smeets      0
# 4   0000-0002-8928-7831        Jaro Camphuijsen      0
# 5   0000-0001-9005-8940            Bouwe Andela      0
# 6   0000-0001-8407-6472       Fakhereh Alidoost      0
# 7   0000-0003-0157-4818             Jerom Aerts      0
# 8   0000-0002-7200-3353      Nick van De Giesen      0
# 9   0000-0001-8367-1333       Gijs van Den Oord      0
# 10  0000-0001-9795-7981             Niels Drost      0
# 11  0000-0002-5697-5697                Rolf Hut      0
# 12  0000-0002-8024-0412          Inti Pelupessy      0
# 13  0000-0002-7508-3272       Ben van Werkhoven      0
# 14  0000-0002-5821-2060        Stefan Verhoeven      0
# 15  0000-0002-5864-6459             Eric Hutton      0
# 16  0000-0002-1774-1126              Bas Crezee      0
# 17  0000-0002-2928-8664            Bettina Gier      0
# 18  0000-0003-2724-709X          Birgit Hassler      0
#  ('0000-0002-0935-0088', '0000-0002-5697-5697'),
#  ('0000-0002-0935-0088', '0000-0002-5025-7862'),
#  ('0000-0001-9795-7981', '0000-0001-9293-9565'),
#  ('0000-0001-9795-7981', '0000-0001-9005-8940'),
#  ('0000-0001-9795-7981', '0000-0003-0157-4818'),
#  ('0000-0001-9795-7981', '0000-0002-9693-9332'),
#  ('0000-0001-9795-7981', '0000-0002-5697-5697'),
#  ('0000-0001-9795-7981', '0000-0002-5025-7862'),
#  ('0000-0001-9293-9565', '0000-0001-9005-8940'),
#  ('0000-0001-9293-9565', '0000-0003-0157-4818'),
#  ('0000-0001-9293-9565', '0000-0002-9693-9332'),
#  ('0000-0001-9293-9565', '0000-0002-5697-5697'),
#  ('0000-0001-9293-9565', '0000-0002-5025-7862'),
#  ('0000-0001-9005-8940', '0000-0003-0157-4818'),
#  ('0000-0001-9005-8940', '0000-0002-9693-9332'),
#  ('0000-0001-9005-8940', '0000-0002-5697-5697'),
#  ('0000-0001-9005-8940', '0000-0002-5025-7862'),
#  ('0000-0003-0157-4818', '0000-0002-9693-9332'),
#  ('0000-0003-0157-4818', '0000-0002-5697-5697'),
#  ('0000-0003-0157-4818', '0000-0002-5025-7862'),
#  ('0000-0002-9693-9332', '0000-0002-5697-5697'),
#  ('0000-0002-9693-9332', '0000-0002-5025-7862'),
#  ('0000-0002-5697-5697', '0000-0002-5025-7862'),
#  ('0000-0002-5025-7862', '0000-0002-8882-5693'),
#  ('0000-0002-5025-7862', '0000-0002-5922-8179'),
#  ('0000-0002-5025-7862', '0000-0003-0995-2481'),
#  ('0000-0002-8882-5693', '0000-0002-5922-8179'),
#  ('0000-0002-8882-5693', '0000-0003-0995-2481'),
#  ('0000-0002-5922-8179', '0000-0003-0995-2481'),
#  ('0000-0002-5025-7862', '0000-0002-8882-5693'),
#  ('0000-0002-5025-7862', '0000-0002-5922-8179'),
#  ('0000-0002-5025-7862', '0000-0003-0995-2481'),
#  ('0000-0002-8882-5693', '0000-0002-5922-8179'),
#  ('0000-0002-8882-5693', '0000-0003-0995-2481'),
#  ('0000-0002-5922-8179', '0000-0003-0995-2481'),
#  ('0000-0002-5025-7862', '0000-0002-5922-8179'),
#  ('0000-0002-5025-7862', '0000-0001-6734-2660'),
#  ('0000-0002-5025-7862', '0000-0003-0995-2481'),
#  ('0000-0002-5922-8179', '0000-0001-6734-2660'),
#  ('0000-0002-5922-8179', '0000-0003-0995-2481'),
#  ('0000-0001-6734-2660', '0000-0003-0995-2481')]

# %% [markdown]
# `preprocess(text)`
#
# This function tokenizes and lemmatizes a given text. It performs the following steps:
#
# - Tokenizes the text using the gensim.utils.simple_preprocess function.
# - Checks if each token is not a stopword and has a length greater than 3.
# - Lemmatizes and stems each token using the lemmatize_stemming function.
# - Returns a list of preprocessed tokens.

# %%
string = "a hh dfhgf iekshj &*O (djahj daj wad d."
topic_modeling.preprocess(string)
# Out:
# ['dfhgf', 'iekshj', 'djahj']

# %% [markdown]
# `orcid_lda_cluster(dois)`
#
# This function performs LDA topic modeling on a collection of DOIs (Document Object Identifiers) and assigns topics to the DOIs. It takes a list of DOIs as input and performs the following steps:
#
# - Preprocesses the abstracts or titles associated with the DOIs using the preprocess(text) function.
# - Creates a dictionary and corpus for the preprocessed data using the gensim.corpora.Dictionary class.
# - Applies LDA topic modeling using the gensim.models.LdaMulticore class with 8 topics, the dictionary, and 10 passes.
# - Retrieves the topic keywords for each topic using the print_topics() method of the LDA model.
# - Stores the topic keywords in the idx2topics dictionary, where the index represents the topic index.
# - Assigns each DOI to the most relevant topic based on the topic with the highest score.
# - Returns the clusters dictionary, which maps each DOI to its assigned topic index, and the idx2topics dictionary, which contains the topic keywords for each topic index.

# %%
topic_modeling.orcid_lda_cluster(doi_list)
# Out:
# ({'10.5194/egusphere-egu21-9387': 0,
#   '10.5194/egusphere-egu21-6051': 0,
#   '10.5194/egusphere-egu21-7797': 0,
#   '10.5194/egusphere-egu21-4805': 0,
#   '10.5194/egusphere-egu21-3476': 1,
#   '10.5194/egusphere-egu21-4895': 0,
#   '10.5194/wes-5-1097-2020': 0,
#   '10.5194/egusphere-egu2020-21619': 0,
#   '10.18174/498797': 5,
#   '10.5194/wes-4-193-2019': 0,
#   '10.5194/wes-2018-79-supplement': 4,
#   '10.1002/we.2267': 6},
#  {0: '0.002*"tool" + 0.002*"model" + 0.002*"data" + 0.002*"recip" + 0.002*"esmvaltool" + 0.002*"scientif" + 0.002*"process" + 0.002*"reproduc" + 0.002*"project" + 0.002*"jat"',
#   1: '0.036*"avail" + 0.024*"download" + 0.024*"data" + 0.022*"model" + 0.020*"option" + 0.018*"command" + 0.016*"jat" + 0.016*"includ" + 0.014*"variabl" + 0.014*"autom"',
#   2: '0.040*"tool" + 0.023*"recip" + 0.019*"diagnost" + 0.018*"user" + 0.017*"test" + 0.014*"commun" + 0.014*"improv" + 0.014*"scientif" + 0.014*"cmip" + 0.013*"evalu"',
#   3: '0.002*"wind" + 0.002*"tool" + 0.002*"data" + 0.002*"model" + 0.002*"infrastructur" + 0.002*"easili" + 0.002*"jat" + 0.002*"access" + 0.002*"workflow" + 0.002*"process"',
#   4: '0.044*"wind" + 0.019*"level" + 0.019*"observ" + 0.014*"data" + 0.014*"cluster" + 0.014*"shape" + 0.014*"speed" + 0.014*"jet" + 0.011*"model" + 0.011*"jat"',
#   5: '0.016*"applic" + 0.016*"wind" + 0.016*"offshor" + 0.016*"energi" + 0.002*"model" + 0.002*"tool" + 0.002*"recip" + 0.002*"data" + 0.002*"esmvaltool" + 0.002*"project"',
#   6: '0.026*"data" + 0.025*"process" + 0.025*"tool" + 0.022*"model" + 0.020*"reproduc" + 0.013*"access" + 0.013*"easili" + 0.013*"infrastructur" + 0.013*"allow" + 0.013*"open"',
#   7: '0.060*"model" + 0.037*"hydrolog" + 0.037*"preprocess" + 0.028*"data" + 0.025*"script" + 0.025*"esmvaltool" + 0.022*"ewatercycl" + 0.019*"forc" + 0.016*"climat" + 0.014*"pipelin"'})
