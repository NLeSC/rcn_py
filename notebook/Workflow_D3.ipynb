# %% [markdown]
# An example pipeline for buiding a Scopus co-authorship network
# ---------------
#
# ### Step 1a: Access Scopus Collection and download the Scopus paper metadata you are interested.
#
# To reach the Scopus document search module, you should use academic IPs. If your institute has been listed in the Scopus database, you have permission to search documents in Scopus. It is not free of charge, and your university should pay its share to Scopus to provide this service for its academic researchers.
#
# If you do not have a academic IP, please skip to [Step 1b](#step-1b) to download the exsiting csv files.
#
# **Why Scopus?**
#
# Scopus has very comprehensive paper data, especially its metadata contains details of authors' affiliations, countries and paper keywords (which are not available on other paper search websites)
#
# **How?**
#
# 1. As the number of papers involving Dutch researchers in just one year is 50,000+, the Scopus API does not offer to handle such a  large amount of data. Therefore, I use the [Scopus Document Search website](https://www.scopus.com/search/form.uri?display=basic#basic) (which requires academic IPs, such as the UvA VPN). The [Advanced Document Search](https://www.scopus.com/search/form.uri?display=advanced) query string is as follows:
#
#     `PUBYEAR  >  2012  AND  PUBYEAR  <  2024  AND  (  LIMIT-TO ( OA ,  "all" ) )  AND  ( LIMIT-TO ( AFFILCOUNTRY ,  "Netherlands" ) )  AND  ( LIMIT-TO ( PUBSTAGE ,  "final" ) )  AND  ( LIMIT-TO ( PUBYEAR ,  2022 ) )  AND  ( LIMIT-TO ( LANGUAGE ,  "English" ) )`
#
#     Using this statement we can get: papers (in 2022) with researchers working in Dutch institutions among the authors, so the authors in the data we obtain are most Dutch researchers, and researchers from other countries who have collaborated with them.
#
# 2. Limit the data scape by choosing one particular **Subject area** in the webpage, and click the *CSV export* button to select information that you want to export. In this project, the following information will be used:
#
#     <img src=../images/scopus_export_setting.png width=50% />
#
#     (*Export restrictions*: If the number of selected papers is greater than 2000, the Affiliations and Author Keywords parameters are not available, so please split the data into csv files containing less than 2000 papers each.)

# %% [markdown]
# ### Step 1b (Optional): Get the downloaded csv files that contains the last ten years papers with Dutch researchers.
#
# You can get the metadata for papers in scopus 2022 with Dutch researchers [here](https://nlesc-my.sharepoint.com/:f:/g/personal/z_bai_esciencecenter_nl/Eig3gDDIRvRAgz9LzP7br1kBVa9e8vMQu6s6y9GDBmDsOQ?e=9zdHF2)

# %% [markdown]
# ### Step 2: Import CSV files to Neo4j Database
#
# 1. Neo4j provides a [fully-managed cloud service](https://neo4j.com/cloud/platform/aura-graph-database/?ref=nav-get-started-cta) (One free AuraDB instance per user, with a limit: 20,000 nodes and 40,000 relationships max)
#
# 2. You can also download [Neo4j Desktop](https://neo4j.com/download/), there is no limit to the sizes (recommanded), and then add *Project* and *Start* it.

# %%
import os
import sys
sys.path.append("..")
from rcn_py import neo4j_scopus
from rcn_py import neo4j_rsd
from rcn_py import openalex
from rcn_py import topic_modeling
from neo4j import GraphDatabase
import pandas as pd

# %% [markdown]
# Connect to your neo4j DB server, obtain your own **uri, username** and **password**

# %%
# local AuraDB example
uri = "bolt://localhost:7687"
user = "neo4j"
password = "zhiningbai"
# uri = "your URI"
# user = "your username"
# password = "your password"

# %% [markdown]
# Check for connection

# %%
check_verify =  GraphDatabase.driver(uri, auth=(user, password))
check_verify.verify_connectivity()

# %% [markdown]
# #### 2.1 Scopus data storage
#
# Change the following to your csv file path.
#
# If you download the csv file from scopus by filtering *Subject area*, please input the following *Subject*.

# %%
filepath = "/Users/jennifer/scopus_data/year2022/Medicine1.csv"
subject = "Medicine"

# %% [markdown]
# Create Constraints

# %%
driver = GraphDatabase.driver(uri, auth=(user, password))
# session = driver.session(database="neo4j")
# session.execute_write(neo4j_scopus.add_constraint) 

# with GraphDatabase.driver(uri, auth=(user, password)) as driver:
with driver.session(database="neo4j") as session:
    session.execute_write(neo4j_scopus.add_constraint) 
# have to do the same thing for rsd!
# CREATE CONSTRAINT orcid IF NOT EXISTS FOR (p:Person) REQUIRE p.orcid IS UNIQUE

# %% [markdown]
# Insert people nodes and publication nodes, and authorship edges to Neo4j DB

# %%
with GraphDatabase.driver(uri, auth=(user, password)) as driver:
    driver.verify_connectivity()
    with driver.session(database="neo4j") as session:
        # Create nodes & edges
        if os.path.exists(filepath):
        # Skipping bad lines (very rare occurrence): 
        # Replace the following line: df = pd.read_csv(path, on_bad_lines = 'skip')
            df = pd.read_csv(filepath)
                    
            # Create "Person" nodes (scopus_id, name, affiliation, country, keywords, year, subject)
            session.execute_write(neo4j_scopus.neo4j_create_people, df, subject) 
            # Create "Publication" nodes (doi, title, year, cited, keywords, subject)
            session.execute_write(neo4j_scopus.neo4j_create_publication, df, subject)
            # Create Relationship "IS_AUTHOR_OF" (scopus_id, doi, author_name, title, year)
            session.execute_write(neo4j_scopus.neo4j_create_author_pub_edge, df)
            print ("Successfully insert " + subject + " csv file.")  
        else:
            print("The file path does not exist!")

# %% [markdown]
# ##### Now you can find data in your Neo4j DB.

# %% [markdown]
# Close DB connection if necessary

# %%
session.close()
driver.close()

# %% [markdown]
# #### 2.2 [Research Software Directory (RSD)](https://research-software-directory.org/) data storage

# %%
projects, authors_proj, software, contributor_soft = neo4j_rsd.request_rsd_data()

# %% [markdown]
# #### Due to the strict Scopus limit (not very friendly), I saved the "get_scopus_info_from_orcid" results to a local JSON file
#
# So first let's get the response data (which are saved as dictionaries) from the files

# %%
# load json module
import json

# %%
with open('../json/rsd_scopus_id_dict.json') as scopus_id_file:
  id_file_contents = scopus_id_file.read()
with open('../json/rsd_preferred_name_dict.json') as preferred_name_file:
  name_file_contents = preferred_name_file.read()
with open('../json/rsd_profilelink_dict.json') as profile_link_file:
  link_file_contents = profile_link_file.read()

scopus_id_dict = json.loads(id_file_contents)
preferred_name_dict = json.loads(name_file_contents)
author_link_dict = json.loads(link_file_contents)

# %% [markdown]
# Add constraints

# %%
driver = GraphDatabase.driver(uri, auth=(user, password))

with driver.session(database="rsd") as session:
    session.execute_write(neo4j_rsd.rsd_add_constraint)

# %% [markdown]
# OK, now we get the scopus-related info by orcids, let's save the data to our Neo4j DB.
#
# ### Run only once:

# %%
with GraphDatabase.driver(uri, auth=(user, password)) as driver:
    driver.verify_connectivity()
    with driver.session(database="rsd") as session:
        # Start creating nodes & edges
        
        # Create "Person" nodes (scopus_id, orcid, name, affiliation)
        session.execute_write(neo4j_rsd.create_person_nodes, authors_proj, scopus_id_dict, preferred_name_dict, author_link_dict) 
        session.execute_write(neo4j_rsd.create_person_nodes, contributor_soft, scopus_id_dict, preferred_name_dict, author_link_dict) 

        # Create "Project" nodes (project_id, title, year, description)
        session.execute_write(neo4j_rsd.create_project_nodes, projects)
        # Create "Software" nodes (software_id, doi, brand_name, year, description)
        session.execute_write(neo4j_rsd.create_software_nodes, software)

        # Create Relationship "IS_AUTHOR_OF" 
        # (scopus_id, project_id/software_id, author_name, title, year)
        session.execute_write(neo4j_rsd.create_author_project_edge, authors_proj, scopus_id_dict, preferred_name_dict, author_link_dict)
        session.execute_write(neo4j_rsd.create_author_software_edge, contributor_soft, scopus_id_dict, preferred_name_dict, author_link_dict)

# %% [markdown]
# Close the drive if it is no longer in use.

# %%
session.close()
driver.close()

# %% [markdown]
# ### Step 3: Read database and map the network

# %% [markdown]
# These are the components of our Web Application:
#
# |  |  |
# | --- | --- |
# | Application Type | Python-Web Application |
# | Web framework | Flask (Micro-Webframework)|
# | Neo4j Database Connector | Neo4j Python Driver for Cypher Docs |
# | Database | Neo4j-Server |
# | Frontend | jquery, bootstrap, d3.js |
#
#
# #### Currently accomplishes the following main functions for visualization:
# 1. A default display (keywork: "Deep learning", year: 2022)
# 2. Simple topic search, and simple author search (the two searches are completely separate)
# 3. information tables and tooltips when clicking on a node
#
#     The tooltip is now unlabelled:
#
#     a. The top left is a "lock" that can lock the node's position', the node will not move even after the tooltip is removed, click the 'lock' button again to unlock it
#     b. The top right is a "remove" button, which, when clicked, removes the node and the nodes only associated with that selected node
#     c. The below is a "expand" key, click on it to get all other relations for that node
#
# 4. drag and zoom

# %%
# uri = "bolt://localhost:7687"
# username = "neo4j"
# password = "zhiningbai"

# %%
# %run ../rcn_d3.py "bolt://localhost:7687" "neo4j" "zhiningbai"

# %% [markdown]
# ##### Or you can run:

# %%
# !python ../rcn_d3.py "bolt://localhost:7687" "neo4j" "zhiningbai"

# %% [markdown]
# ### Let's try OpenAlex

# %% [markdown]
# Pre-load some aff-related works

# %%
institution_name = "Netherlands eScience Center"
all_works_of_one_institution = openalex.get_all_works_of_one_institution(institution_name)

# %%
all_works_of_one_institution

# %%
first_work = all_works_of_one_institution[0]

# %%
first_work['concepts']
# Out:
# [{'id': 'https://openalex.org/C2777950569',
#   'wikidata': 'https://www.wikidata.org/wiki/Q17021836',
#   'display_name': 'Stewardship (theology)',
#   'level': 3,
#   'score': 0.7497333},
#  {'id': 'https://openalex.org/C206588197',
#   'wikidata': 'https://www.wikidata.org/wiki/Q846574',
#   'display_name': 'Reuse',
#   'level': 2,
#   'score': 0.69452894},
#  {'id': 'https://openalex.org/C137981799',
#   'wikidata': 'https://www.wikidata.org/wiki/Q1369184',
#   'display_name': 'Reusability',
#   'level': 3,
#   'score': 0.6708406},
#  {'id': 'https://openalex.org/C26713055',
#   'wikidata': 'https://www.wikidata.org/wiki/Q245962',
#   'display_name': 'Implementation',
#   'level': 2,
#   'score': 0.64504087},
#  {'id': 'https://openalex.org/C41008148',
#   'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#   'display_name': 'Computer science',
#   'level': 0,
#   'score': 0.5673512},
#  {'id': 'https://openalex.org/C177264268',
#   'wikidata': 'https://www.wikidata.org/wiki/Q1514741',
#   'display_name': 'Set (abstract data type)',
#   'level': 2,
#   'score': 0.5325398},
#  {'id': 'https://openalex.org/C2522767166',
#   'wikidata': 'https://www.wikidata.org/wiki/Q2374463',
#   'display_name': 'Data science',
#   'level': 1,
#   'score': 0.43399763},
#  {'id': 'https://openalex.org/C56739046',
#   'wikidata': 'https://www.wikidata.org/wiki/Q192060',
#   'display_name': 'Knowledge management',
#   'level': 1,
#   'score': 0.43278173},
#  {'id': 'https://openalex.org/C2780182762',
#   'wikidata': 'https://www.wikidata.org/wiki/Q1630279',
#   'display_name': 'Guideline',
#   'level': 2,
#   'score': 0.42063028},
#  {'id': 'https://openalex.org/C177212765',
#   'wikidata': 'https://www.wikidata.org/wiki/Q627335',
#   'display_name': 'Workflow',
#   'level': 2,
#   'score': 0.41600522},
#  {'id': 'https://openalex.org/C55587333',
#   'wikidata': 'https://www.wikidata.org/wiki/Q1133029',
#   'display_name': 'Engineering ethics',
#   'level': 1,
#   'score': 0.3947078},
#  {'id': 'https://openalex.org/C195094911',
#   'wikidata': 'https://www.wikidata.org/wiki/Q14167904',
#   'display_name': 'Process management',
#   'level': 1,
#   'score': 0.32888448},
#  {'id': 'https://openalex.org/C144133560',
#   'wikidata': 'https://www.wikidata.org/wiki/Q4830453',
#   'display_name': 'Business',
#   'level': 0,
#   'score': 0.30317992},
#  {'id': 'https://openalex.org/C17744445',
#   'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#   'display_name': 'Political science',
#   'level': 0,
#   'score': 0.30032963},
#  {'id': 'https://openalex.org/C115903868',
#   'wikidata': 'https://www.wikidata.org/wiki/Q80993',
#   'display_name': 'Software engineering',
#   'level': 1,
#   'score': 0.18008342},
#  {'id': 'https://openalex.org/C77088390',
#   'wikidata': 'https://www.wikidata.org/wiki/Q8513',
#   'display_name': 'Database',
#   'level': 1,
#   'score': 0.1218684},
#  {'id': 'https://openalex.org/C127413603',
#   'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#   'display_name': 'Engineering',
#   'level': 0,
#   'score': 0.11883542},
#  {'id': 'https://openalex.org/C199539241',
#   'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#   'display_name': 'Law',
#   'level': 1,
#   'score': 0.080988705},
#  {'id': 'https://openalex.org/C199360897',
#   'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#   'display_name': 'Programming language',
#   'level': 1,
#   'score': 0.0},
#  {'id': 'https://openalex.org/C548081761',
#   'wikidata': 'https://www.wikidata.org/wiki/Q180388',
#   'display_name': 'Waste management',
#   'level': 1,
#   'score': 0.0},
#  {'id': 'https://openalex.org/C2777904410',
#   'wikidata': 'https://www.wikidata.org/wiki/Q7397',
#   'display_name': 'Software',
#   'level': 2,
#   'score': 0.0},
#  {'id': 'https://openalex.org/C94625758',
#   'wikidata': 'https://www.wikidata.org/wiki/Q7163',
#   'display_name': 'Politics',
#   'level': 2,
#   'score': 0.0}]

# %%
institution_info_list = []
id = 0
for work in all_works_of_one_institution:
    for au in work['authorships']:
        for inst in au['institutions']:
            if inst['id'] and inst not in institution_info_list:
                inst['node_id'] = id
                institution_info_list.append(inst)
                id +=1
institution_info_list

# %%
institution_info_list

# %%
    
all_institution_info_list = []
for work in all_works_of_one_institution:
        current_work_inst_list = []
        for au in work['authorships']:
            for inst in au['institutions']:
                if inst['id'] and  inst not in current_work_inst_list:
                    current_work_inst_list.append(inst)
        all_institution_info_list.append(current_work_inst_list)
        
all_institution_info_list

# %%
node_id = 0 # node_id is from 0
all_institution_info_list = [] # Node info (no duplication)
all_inst_id_list = [] # Used to check whether the institution has been saved
for work in all_works_of_one_institution:
        current_work_inst_id_list = []
        for au in work['authorships']:
            for inst in au['institutions']:
                if inst['id']:
                    if inst['id'] in all_inst_id_list:
                        existing_index = all_inst_id_list.index(inst['id'])
                        # Get the exsiting node id 
                        if existing_index not in current_work_inst_id_list:
                            current_work_inst_id_list.append(existing_index)
                    else:
                        inst['node_id'] = node_id
                        all_institution_info_list.append(inst)
                        all_inst_id_list.append(inst['id'])
                        current_work_inst_id_list.append(node_id)
                        
                        node_id += 1
        print(current_work_inst_id_list)

# %%
import gensim
from gensim import corpora

# %%
keywords_list = []
works = openalex.get_works_of_one_institution_by_year("Netherlands eScience Center", '2023','2023')
for w in works:
    keywords = openalex.publication_keywords(w['doi'])
    keywords_list.append(keywords)
keywords_list
# Out:
# [['Sustainability',
#   'Software',
#   'Computer science',
#   'Business',
#   'Software engineering',
#   'Environmental planning',
#   'Environmental resource management',
#   'Environmental science',
#   'Operating system',
#   'Biology'],
#  ['Ecosystem',
#   'Environmental science',
#   'Environmental resource management',
#   'Psychological resilience',
#   'Climate change',
#   'Ecosystem services',
#   'Resilience (materials science)',
#   'Ecology',
#   'Biology',
#   'Physics'],
#  ['Mesoscale meteorology',
#   'Cloud computing',
#   'Meteorology',
#   'Convection',
#   'Large eddy simulation',
#   'Scale (ratio)',
#   'Geology',
#   'Atmospheric sciences',
#   'Computer science',
#   'Geography'],
#  ['Transformer',
#   'Computer science',
#   'Architecture',
#   'Deep learning',
#   'Artificial intelligence',
#   'Proteomics',
#   'Mass spectrometry',
#   'Machine learning',
#   'Engineering',
#   'Chemistry'],
#  ['Python (programming language)',
#   'Scripting language',
#   'Upload',
#   'Computer science',
#   'Software',
#   'Download',
#   'Programming language',
#   'Summer camp',
#   'World Wide Web',
#   'Operating system'],
#  ['Cluster analysis',
#   'Computer science',
#   'Python (programming language)',
#   'Data mining',
#   'Software',
#   'Set (abstract data type)',
#   'Artificial intelligence',
#   'Programming language',
#   'Operating system'],
#  ['Eddy covariance',
#   'FluxNet',
#   'Environmental science',
#   'Carbon flux',
#   'Atmospheric sciences',
#   'Ecosystem',
#   'Atmosphere (unit)',
#   'Land cover',
#   'Carbon cycle',
#   'Flux (metallurgy)'],
#  ['Receipt',
#   'Climate change',
#   'Climate model',
#   'Computer science',
#   'Data science',
#   'World Wide Web',
#   'Ecology',
#   'Biology'],
#  ['Interoperability',
#   'Computer science',
#   'Workflow',
#   'Open science',
#   'Ecosystem',
#   'Environmental resource management',
#   'Earth science',
#   'World Wide Web',
#   'Environmental science',
#   'Ecology'],
#  ['Glacier',
#   'Python (programming language)',
#   'Toolbox',
#   'Elevation (ballistics)',
#   'Computer science',
#   'Climate change',
#   'Remote sensing',
#   'Change detection',
#   'Digital elevation model',
#   'Geology'],
#  ['Precipitation',
#   'Flood myth',
#   'Hydrometeorology',
#   'Environmental science',
#   'Moisture',
#   'Climatology',
#   'Vegetation (pathology)',
#   'Event (particle physics)',
#   'Atmospheric sciences',
#   'Physical geography'],
#  ['Relevance (law)',
#   'Credibility',
#   'Climate change',
#   'Service provider',
#   'Domain (mathematical analysis)',
#   'Service (business)',
#   'Computer science',
#   'Process management',
#   'Knowledge management',
#   'Business'],
#  ['Data assimilation',
#   'Standard deviation',
#   'Environmental science',
#   'Kalman filter',
#   'Meteorology',
#   'Mathematics',
#   'Statistics',
#   'Geography'],
#  ['Computer science',
#   'Core model',
#   'Climate model',
#   'Grid',
#   'Computational science',
#   'Multi-core processor',
#   'Parallel computing',
#   'Climate change',
#   'Geology',
#   'Mathematical analysis'],
#  ['Earth system science',
#   'Computer science',
#   'Workflow',
#   'Climate model',
#   'Grid',
#   'Adaptation (eye)',
#   'Climate change',
#   'Systems engineering',
#   'Distributed computing',
#   'Database'],
#  ['Computer science',
#   'Python (programming language)',
#   'Synthetic aperture radar',
#   'Workflow',
#   'Stack (abstract data type)',
#   'Interferometric synthetic aperture radar',
#   'Remote sensing',
#   'Real-time computing',
#   'Artificial intelligence',
#   'Geology'],
#  ['Advection',
#   'Dispersion (optics)',
#   'Computer science',
#   'Inlet',
#   'Meteorology',
#   'Environmental science',
#   'Algorithm',
#   'Marine engineering',
#   'Geology',
#   'Geography'],
#  ['Computer science',
#   'Standardization',
#   'Predictability',
#   'Python (programming language)',
#   'Preprocessor',
#   'Raw data',
#   'Artificial intelligence',
#   'Machine learning',
#   'Workflow',
#   'Data science'],
#  ['Workflow',
#   'Computer science',
#   'Presentation (obstetrics)',
#   'Coupling (piping)',
#   'Sample (material)',
#   'Software engineering',
#   'Work (physics)',
#   'Hydrological modelling',
#   'Data science',
#   'Hydrology (agriculture)'],
#  ['Environmental science',
#   'Transpiration',
#   'Water content',
#   'Evapotranspiration',
#   'Soil science',
#   'Atmospheric sciences',
#   'Hydrology (agriculture)',
#   'Photosynthesis',
#   'Ecology',
#   'Chemistry'],
#  ['Gammarus pulex',
#   'Startle response',
#   'Biology',
#   'Ecology',
#   'Pulex',
#   'Crustacean',
#   'Amphipoda',
#   'Neuroscience',
#   'Daphnia'],
#  ['Gammarus pulex',
#   'Fluoxetine',
#   'Pulex',
#   'Thigmotaxis',
#   'Open field',
#   'Antidepressant',
#   'Toxicology',
#   'Amphipoda',
#   'Chemistry',
#   'Biology'],
#  ['Computer science',
#   'Software',
#   'Software engineering',
#   'Programming language'],
#  ['Crystallite',
#   'Chemistry',
#   'Diffraction',
#   'Phase (matter)',
#   'Throughput',
#   'Electron diffraction',
#   'Electron crystallography',
#   'Crystallography',
#   'Nanotechnology',
#   'Materials science'],
#  ['Microbiome',
#   'Species evenness',
#   'Biology',
#   'Ecology',
#   'Biodiversity',
#   'Range (aeronautics)',
#   'Ecosystem',
#   'Butterfly',
#   'Alpha diversity',
#   'Habitat'],
#  ['Flagging',
#   'Physics',
#   'Electromagnetic interference',
#   'Interference (communication)',
#   'Calibration',
#   'Radio telescope',
#   'Detector',
#   'Computer science',
#   'Astrophysics',
#   'Optics'],
#  ['Computer science',
#   'Earth system science',
#   'Workflow',
#   'Pipeline (software)',
#   'Climate model',
#   'Extension (predicate logic)',
#   'Process (computing)',
#   'Coupled model intercomparison project',
#   'Preprocessor',
#   'Systems engineering'],
#  ['Major histocompatibility complex',
#   'MHC class I',
#   'Computer science',
#   'Computational biology',
#   'Antigen presentation',
#   'Antigen processing',
#   'CD8',
#   'Biology',
#   'Antigen',
#   'T cell']]

# %%
dictionary = corpora.Dictionary(keywords_list)
corpus = [dictionary.doc2bow(keywords) for keywords in keywords_list]

# Train LDA Model
# num_topics = 10  # Specify the number of topics
lda_model = gensim.models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=10)

# Get Topics and Assign Topic Names
topics = lda_model.print_topics(num_words=5)  # Specify the number of words per topic

topic_lists = []
for t in topics:
    top_keywords = [word.split("*")[1].strip().replace('"', '') for word in t[1].split("+")]
    topic_lists.append(top_keywords)

# Count the frequency of each word
word_counts = {}
for topic in topic_lists:
    for word in topic:
        word_counts[word] = word_counts.get(word, 0) + 1

# Remove words that appear in more than half of the lists
filtered_topics = []
threshold = len(topic_lists) / 2
for topic in topic_lists:
    filtered_topic = [word for word in topic if word_counts[word] <= threshold]
    filtered_topics.append(filtered_topic)

# Print and Save Topic Names
topic_names = {}
for i, publication in enumerate(works):
        publication_topics = lda_model.get_document_topics(corpus[i])
        top_topic = max(publication_topics, key=lambda x: x[1])[0]  # Get the topic with the highest weight for the publication
        top_keywords = filtered_topics[top_topic]
        topic_names[top_topic] = ", ".join(top_keywords)
        # topic_names[i] = {"topic_name": ", ".join(top_keywords), "group_id": top_topic}
        
        # publication["topic_name"] = top_keywords
        # publication["group_id"] = top_topic
print(topic_names)
# Out:
# {3: 'Biology, Climate change, Business', 0: 'Workflow, Geology, Python (programming language), Climate change', 4: 'Programming language, Software, Operating system, Python (programming language)', 2: 'Ecosystem, Biology, Geography', 1: 'Ecology, Workflow, Hydrology (agriculture)'}

# %%
openalex.get_works_of_one_institution("Netherlands eScience Center", 50)

# %%
works_url = openalex.find_institution("Netherlands eScience Center")['results'][0]['works_api_url']

# %%
import requests

start_year = '2022'
end_year = '2023'
api_url = works_url+',publication_year:'+start_year+'-'+ end_year + '&sort=publication_date:desc'
header = {'Accept' : 'application/json'}

params = {
            'per_page': 100,  # Number of results per page
            'page': 1       # Initial page number
        }
openalex_aff_search = []

while True:
            resp = requests.get(api_url, headers=header, params=params)
            work_search_per_page = resp.json()
            openalex_aff_search.extend(work_search_per_page['results'])
            total_results = work_search_per_page['meta']['count']
            current_page = work_search_per_page['meta']['page']
            results_per_page = work_search_per_page['meta']['per_page']

            total_pages = (total_results + results_per_page - 1) // results_per_page
            if current_page == total_pages:
                break  # Break the loop when all pages have been retrieved

            params['page'] += 1

# %%
openalex_aff_search

# %%
works = openalex.get_works_of_one_institution_by_year("Netherlands eScience Center", '2023','2023')
topic_modeling.openalex_build_corpus(works,5)
# Out:
# ({4: 'Workflow, Environmental science, Software engineering, Software',
#   0: 'Python (programming language), Biology, Artificial intelligence, Geology',
#   3: 'Atmospheric sciences, Environmental science, Ecology, Ecosystem, Chemistry',
#   1: 'Climate model, Climate change, Grid, Earth system science',
#   2: 'Chemistry, Gammarus pulex, Pulex, Amphipoda'},
#  [{'id': 'https://openalex.org/W4378737443',
#    'doi': 'https://doi.org/10.5281/zenodo.7951155',
#    'title': 'Report on the Workshop on Sustainable Software Sustainability 2021 (WoSSS21)',
#    'display_name': 'Report on the Workshop on Sustainable Software Sustainability 2021 (WoSSS21)',
#    'publication_year': 2023,
#    'publication_date': '2023-05-30',
#    'ids': {'openalex': 'https://openalex.org/W4378737443',
#     'doi': 'https://doi.org/10.5281/zenodo.7951155'},
#    'language': 'en',
#    'primary_location': {'is_oa': True,
#     'landing_page_url': 'https://zenodo.org/record/7951155',
#     'pdf_url': 'https://zenodo.org/record/7951155/files/Report%20on%20the%20Workshop%20on%20Sustainable%20Software%20Sustainability%202021%20%28WoSSS21%29.pdf',
#     'source': {'id': 'https://openalex.org/S4306400562',
#      'display_name': 'Zenodo (CERN European Organization for Nuclear Research)',
#      'issn_l': None,
#      'issn': None,
#      'host_organization': 'https://openalex.org/I67311998',
#      'host_organization_name': 'European Organization for Nuclear Research',
#      'host_organization_lineage': ['https://openalex.org/I67311998'],
#      'host_organization_lineage_names': ['European Organization for Nuclear Research'],
#      'type': 'repository'},
#     'license': 'cc-by',
#     'version': 'submittedVersion'},
#    'type': 'report',
#    'open_access': {'is_oa': True,
#     'oa_status': 'closed',
#     'oa_url': 'https://zenodo.org/record/7951155/files/Report%20on%20the%20Workshop%20on%20Sustainable%20Software%20Sustainability%202021%20%28WoSSS21%29.pdf',
#     'any_repository_has_fulltext': True},
#    'authorships': [{'author_position': 'first',
#      'author': {'id': 'https://openalex.org/A4378739024',
#       'display_name': 'Shoaib Sufi',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I28407311',
#        'display_name': 'University of Manchester',
#        'ror': 'https://ror.org/027m9bs27',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Manchester',
#      'raw_affiliation_strings': ['University of Manchester']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739025',
#       'display_name': 'Carlos Martinez-Ortiz',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands eScience Center',
#      'raw_affiliation_strings': ['Netherlands eScience Center']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739026',
#       'display_name': 'Peter Doorn',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210089348',
#        'display_name': 'Data Archiving and Networked Services',
#        'ror': 'https://ror.org/008pnp284',
#        'country_code': 'NL',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Data Archiving and Networked Services',
#      'raw_affiliation_strings': ['Data Archiving and Networked Services']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739027',
#       'display_name': 'Jessica Farrell',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210129574',
#        'display_name': 'Educopia Institute',
#        'ror': 'https://ror.org/03z3dqe20',
#        'country_code': 'US',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Educopia Institute',
#      'raw_affiliation_strings': ['Educopia Institute']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739028',
#       'display_name': 'Michelle Barker',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210130202',
#        'display_name': 'Software Research Associates (Japan)',
#        'ror': 'https://ror.org/02frcze54',
#        'country_code': 'JP',
#        'type': 'company'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Research Software Alliance (ReSA)',
#      'raw_affiliation_strings': ['Research Software Alliance (ReSA)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739029',
#       'display_name': 'Daniel S. Katz',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I157725225',
#        'display_name': 'University of Illinois Urbana-Champaign',
#        'ror': 'https://ror.org/047426m28',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Illinois at Urbana-Champaign',
#      'raw_affiliation_strings': ['University of Illinois at Urbana-Champaign']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739030',
#       'display_name': 'Adam Jackson',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I162524378',
#        'display_name': 'Science and Technology Facilities Council',
#        'ror': 'https://ror.org/057g20z61',
#        'country_code': 'GB',
#        'type': 'government'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Science & Technology Facilities Council (UKRI STFC)',
#      'raw_affiliation_strings': ['Science & Technology Facilities Council (UKRI STFC)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739031',
#       'display_name': 'Alexander Struck',
#       'orcid': None},
#      'institutions': [{'id': None,
#        'display_name': 'Humboldt University of Berlin',
#        'ror': None,
#        'country_code': None,
#        'type': None}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Humboldt University of Berlin',
#      'raw_affiliation_strings': ['Humboldt University of Berlin']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739032',
#       'display_name': 'Andrew Sandeman',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I143804889',
#        'display_name': 'Loughborough University',
#        'ror': 'https://ror.org/04vg4w365',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Loughborough University',
#      'raw_affiliation_strings': ['Loughborough University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739033',
#       'display_name': 'Andrew Stewart',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I28407311',
#        'display_name': 'University of Manchester',
#        'ror': 'https://ror.org/027m9bs27',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Manchester',
#      'raw_affiliation_strings': ['University of Manchester']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739034',
#       'display_name': 'Andy R. Terrel',
#       'orcid': None},
#      'institutions': [{'id': None,
#        'display_name': 'StoryFit',
#        'ror': None,
#        'country_code': None,
#        'type': None}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'StoryFit',
#      'raw_affiliation_strings': ['StoryFit']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739035',
#       'display_name': 'Ben Companjen',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I121797337',
#        'display_name': 'Leiden University',
#        'ror': 'https://ror.org/027bh9e22',
#        'country_code': 'NL',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Leiden University',
#      'raw_affiliation_strings': ['Leiden University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739036',
#       'display_name': 'Carina Haupt',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I2898391981',
#        'display_name': 'German Aerospace Center',
#        'ror': 'https://ror.org/04bwf3e34',
#        'country_code': 'DE',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'German Aerospace Center (DLR)',
#      'raw_affiliation_strings': ['German Aerospace Center (DLR)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739037',
#       'display_name': 'Carly Strasser',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210121800',
#        'display_name': 'Chan Zuckerberg Initiative (United States)',
#        'ror': 'https://ror.org/02qenvm24',
#        'country_code': 'US',
#        'type': 'company'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Chan Zuckerberg Initiative (CZI)',
#      'raw_affiliation_strings': ['Chan Zuckerberg Initiative (CZI)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739038',
#       'display_name': 'Carole Goble',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I28407311',
#        'display_name': 'University of Manchester',
#        'ror': 'https://ror.org/027m9bs27',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Manchester',
#      'raw_affiliation_strings': ['University of Manchester']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739039',
#       'display_name': 'Christina Von Flach Garcia Chavez',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I126158947',
#        'display_name': 'Federal University of Bahia',
#        'ror': 'https://ror.org/03k3p7647',
#        'country_code': 'BR',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Federal University of Bahia',
#      'raw_affiliation_strings': ['Federal University of Bahia']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739040',
#       'display_name': 'Colin Venters',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I67311998',
#        'display_name': 'European Organization for Nuclear Research',
#        'ror': 'https://ror.org/01ggx4157',
#        'country_code': 'CH',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'CERN',
#      'raw_affiliation_strings': ['CERN']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739041',
#       'display_name': 'Dianne Dietrich',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I205783295',
#        'display_name': 'Cornell University',
#        'ror': 'https://ror.org/05bnh6r87',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Cornell University',
#      'raw_affiliation_strings': ['Cornell University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739042',
#       'display_name': 'Elena Colón-Marrero',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I27837315',
#        'display_name': 'University of Michigan–Ann Arbor',
#        'ror': 'https://ror.org/00jmfr291',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Michigan',
#      'raw_affiliation_strings': ['University of Michigan']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739043',
#       'display_name': 'Emma Irwin',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210164937',
#        'display_name': 'Microsoft Research (United Kingdom)',
#        'ror': 'https://ror.org/05k87vq12',
#        'country_code': 'GB',
#        'type': 'company'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Microsoft',
#      'raw_affiliation_strings': ['Microsoft']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739044',
#       'display_name': 'Euan Cochrane',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I32971472',
#        'display_name': 'Yale University',
#        'ror': 'https://ror.org/03v76x132',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Yale University',
#      'raw_affiliation_strings': ['Yale University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739045',
#       'display_name': 'Fakhereh (Sarah) Alidoost',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands eScience Centre',
#      'raw_affiliation_strings': ['Netherlands eScience Centre']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739046',
#       'display_name': 'Fotis Psomopoulos',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210134249',
#        'display_name': 'Centre for Research and Technology Hellas',
#        'ror': 'https://ror.org/03bndpq63',
#        'country_code': 'GR',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Centre for Research & Technology Hellas (CERTH)',
#      'raw_affiliation_strings': ['Centre for Research & Technology Hellas (CERTH)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739047',
#       'display_name': 'Gerard Coen',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210089348',
#        'display_name': 'Data Archiving and Networked Services',
#        'ror': 'https://ror.org/008pnp284',
#        'country_code': 'NL',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Data Archiving and Networked Services (DANS)',
#      'raw_affiliation_strings': ['Data Archiving and Networked Services (DANS)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739048',
#       'display_name': 'Hilary Szu Yin Shiue',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I66946132',
#        'display_name': 'University of Maryland, College Park',
#        'ror': 'https://ror.org/047s2c258',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Maryland',
#      'raw_affiliation_strings': ['University of Maryland']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739049',
#       'display_name': 'Ignacio Blanquer',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I60053951',
#        'display_name': 'Universitat Politècnica de València',
#        'ror': 'https://ror.org/01460j859',
#        'country_code': 'ES',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Valencia Polytechnic University',
#      'raw_affiliation_strings': ['Valencia Polytechnic University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739050',
#       'display_name': 'Jean-Noël Grad',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I100066346',
#        'display_name': 'University of Stuttgart',
#        'ror': 'https://ror.org/04vnq7t77',
#        'country_code': 'DE',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Stuttgart',
#      'raw_affiliation_strings': ['University of Stuttgart']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739051',
#       'display_name': 'Jesse de Vos',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I2801405528',
#        'display_name': 'Netherlands Institute for Sound and Vision',
#        'ror': 'https://ror.org/025ae8628',
#        'country_code': 'NL',
#        'type': 'archive'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands Institute for Sound & Vision (NISV)',
#      'raw_affiliation_strings': ['Netherlands Institute for Sound & Vision (NISV)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739052',
#       'display_name': 'Jessica Meyerson',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210129574',
#        'display_name': 'Educopia Institute',
#        'ror': 'https://ror.org/03z3dqe20',
#        'country_code': 'US',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Educopia Institute',
#      'raw_affiliation_strings': ['Educopia Institute']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739053',
#       'display_name': 'Kelly Rosa Braghetto',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I1325072066',
#        'display_name': 'WiLAN (Canada)',
#        'ror': 'https://ror.org/051pbge72',
#        'country_code': 'CA',
#        'type': 'company'},
#       {'id': 'https://openalex.org/I17974374',
#        'display_name': 'Universidade de São Paulo',
#        'ror': 'https://ror.org/036rp1748',
#        'country_code': 'BR',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of São Paulo',
#      'raw_affiliation_strings': ['University of São Paulo']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739054',
#       'display_name': 'Konstantinos Repanas',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I2800387288',
#        'display_name': 'European Commission',
#        'ror': 'https://ror.org/00k4n6c32',
#        'country_code': 'BE',
#        'type': 'government'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'European Commission',
#      'raw_affiliation_strings': ['European Commission']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739055',
#       'display_name': 'Martin Hammitzsch',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210152878',
#        'display_name': 'Helmholtz Centre Potsdam - GFZ German Research Centre for Geosciences',
#        'ror': 'https://ror.org/04z8jg394',
#        'country_code': 'DE',
#        'type': 'facility'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Helmholtz Centre Potsdam',
#      'raw_affiliation_strings': ['Helmholtz Centre Potsdam']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739056',
#       'display_name': 'Meta Keijzer-de Ruijter',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I98358874',
#        'display_name': 'Delft University of Technology',
#        'ror': 'https://ror.org/02e2c7k09',
#        'country_code': 'NL',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Delft University of Technology (TU Delft)',
#      'raw_affiliation_strings': ['Delft University of Technology (TU Delft)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739057',
#       'display_name': 'Michael Courtney',
#       'orcid': None},
#      'institutions': [{'id': None,
#        'display_name': 'Catholic Diocese of Salt Lake City',
#        'ror': None,
#        'country_code': None,
#        'type': None}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Catholic Diocese of Salt Lake City',
#      'raw_affiliation_strings': ['Catholic Diocese of Salt Lake City']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739058',
#       'display_name': 'Morane Gruenpeter',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I1326498283',
#        'display_name': 'French Institute for Research in Computer Science and Automation',
#        'ror': 'https://ror.org/02kvxyf05',
#        'country_code': 'FR',
#        'type': 'government'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Inria',
#      'raw_affiliation_strings': ['Inria']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739059',
#       'display_name': 'Mustafa Doğan',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I74656192',
#        'display_name': 'University of Göttingen',
#        'ror': 'https://ror.org/01y9bpm73',
#        'country_code': 'DE',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Göttingen',
#      'raw_affiliation_strings': ['University of Göttingen']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739060',
#       'display_name': 'Neil Chue Hong',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I98677209',
#        'display_name': 'University of Edinburgh',
#        'ror': 'https://ror.org/01nrxwf90',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Edinburgh',
#      'raw_affiliation_strings': ['University of Edinburgh']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739061',
#       'display_name': 'Nicolas M. Thiéry',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I102197404',
#        'display_name': 'University of Paris-Sud',
#        'ror': 'https://ror.org/028rypz17',
#        'country_code': 'FR',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Paris-Sud University',
#      'raw_affiliation_strings': ['Paris-Sud University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739062',
#       'display_name': 'Otigbu Austine',
#       'orcid': None},
#      'institutions': [{'id': None,
#        'display_name': 'National Archives of Nigeria',
#        'ror': None,
#        'country_code': None,
#        'type': None}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'National Archives of Nigeria',
#      'raw_affiliation_strings': ['National Archives of Nigeria']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739063',
#       'display_name': 'Pamela Nye',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210115001',
#        'display_name': 'Westminster Schools',
#        'ror': 'https://ror.org/02ammvg77',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'The Westminster Schools',
#      'raw_affiliation_strings': ['The Westminster Schools']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739064',
#       'display_name': 'Patricia Falcão',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210135923',
#        'display_name': 'Tate',
#        'ror': 'https://ror.org/04s55st49',
#        'country_code': 'GB',
#        'type': 'other'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Tate',
#      'raw_affiliation_strings': ['Tate']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739065',
#       'display_name': 'Paula Andrea Martinez',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210128169',
#        'display_name': 'Australian Research Data Commons',
#        'ror': 'https://ror.org/038sjwq14',
#        'country_code': 'AU',
#        'type': 'other'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Australian Research Data Commons (ARDC)',
#      'raw_affiliation_strings': ['Australian Research Data Commons (ARDC)']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739066',
#       'display_name': 'Rachael Ainsworth',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I28407311',
#        'display_name': 'University of Manchester',
#        'ror': 'https://ror.org/027m9bs27',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Manchester',
#      'raw_affiliation_strings': ['University of Manchester']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739067',
#       'display_name': 'Raniere Silva',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I168719708',
#        'display_name': 'City University of Hong Kong',
#        'ror': 'https://ror.org/03q8dnn23',
#        'country_code': 'CN',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'City University of Hong Kong',
#      'raw_affiliation_strings': ['City University of Hong Kong']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739068',
#       'display_name': 'Scott Kirycki',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I107639228',
#        'display_name': 'University of Notre Dame',
#        'ror': 'https://ror.org/00mkhxb43',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Notre Dame',
#      'raw_affiliation_strings': ['University of Notre Dame']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739069',
#       'display_name': 'Stian Soiland-Reyes',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I28407311',
#        'display_name': 'University of Manchester',
#        'ror': 'https://ror.org/027m9bs27',
#        'country_code': 'GB',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Manchester',
#      'raw_affiliation_strings': ['University of Manchester']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378739070',
#       'display_name': 'Tom Honeyman',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210128169',
#        'display_name': 'Australian Research Data Commons',
#        'ror': 'https://ror.org/038sjwq14',
#        'country_code': 'AU',
#        'type': 'other'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Australian Research Data Commons (ARDC)',
#      'raw_affiliation_strings': ['Australian Research Data Commons (ARDC)']},
#     {'author_position': 'last',
#      'author': {'id': 'https://openalex.org/A4378739071',
#       'display_name': 'Vicky Rampin',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I57206974',
#        'display_name': 'New York University',
#        'ror': 'https://ror.org/0190ak572',
#        'country_code': 'US',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'New York University',
#      'raw_affiliation_strings': ['New York University']}],
#    'corresponding_author_ids': [],
#    'corresponding_institution_ids': [],
#    'apc_payment': None,
#    'cited_by_count': 0,
#    'biblio': {'volume': None,
#     'issue': None,
#     'first_page': None,
#     'last_page': None},
#    'is_retracted': False,
#    'is_paratext': False,
#    'concepts': [{'id': 'https://openalex.org/C66204764',
#      'wikidata': 'https://www.wikidata.org/wiki/Q219416',
#      'display_name': 'Sustainability',
#      'level': 2,
#      'score': 0.7756845},
#     {'id': 'https://openalex.org/C2777904410',
#      'wikidata': 'https://www.wikidata.org/wiki/Q7397',
#      'display_name': 'Software',
#      'level': 2,
#      'score': 0.50123405},
#     {'id': 'https://openalex.org/C41008148',
#      'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#      'display_name': 'Computer science',
#      'level': 0,
#      'score': 0.4102248},
#     {'id': 'https://openalex.org/C144133560',
#      'wikidata': 'https://www.wikidata.org/wiki/Q4830453',
#      'display_name': 'Business',
#      'level': 0,
#      'score': 0.371998},
#     {'id': 'https://openalex.org/C115903868',
#      'wikidata': 'https://www.wikidata.org/wiki/Q80993',
#      'display_name': 'Software engineering',
#      'level': 1,
#      'score': 0.342363},
#     {'id': 'https://openalex.org/C91375879',
#      'wikidata': 'https://www.wikidata.org/wiki/Q15473274',
#      'display_name': 'Environmental planning',
#      'level': 1,
#      'score': 0.32879606},
#     {'id': 'https://openalex.org/C107826830',
#      'wikidata': 'https://www.wikidata.org/wiki/Q929380',
#      'display_name': 'Environmental resource management',
#      'level': 1,
#      'score': 0.3246219},
#     {'id': 'https://openalex.org/C39432304',
#      'wikidata': 'https://www.wikidata.org/wiki/Q188847',
#      'display_name': 'Environmental science',
#      'level': 0,
#      'score': 0.18620083},
#     {'id': 'https://openalex.org/C111919701',
#      'wikidata': 'https://www.wikidata.org/wiki/Q9135',
#      'display_name': 'Operating system',
#      'level': 1,
#      'score': 0.09036243},
#     {'id': 'https://openalex.org/C86803240',
#      'wikidata': 'https://www.wikidata.org/wiki/Q420',
#      'display_name': 'Biology',
#      'level': 0,
#      'score': 0.08322188},
#     {'id': 'https://openalex.org/C18903297',
#      'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#      'display_name': 'Ecology',
#      'level': 1,
#      'score': 0.073293865}],
#    'mesh': [],
#    'locations_count': 1,
#    'locations': [{'is_oa': True,
#      'landing_page_url': 'https://zenodo.org/record/7951155',
#      'pdf_url': 'https://zenodo.org/record/7951155/files/Report%20on%20the%20Workshop%20on%20Sustainable%20Software%20Sustainability%202021%20%28WoSSS21%29.pdf',
#      'source': {'id': 'https://openalex.org/S4306400562',
#       'display_name': 'Zenodo (CERN European Organization for Nuclear Research)',
#       'issn_l': None,
#       'issn': None,
#       'host_organization': 'https://openalex.org/I67311998',
#       'host_organization_name': 'European Organization for Nuclear Research',
#       'host_organization_lineage': ['https://openalex.org/I67311998'],
#       'host_organization_lineage_names': ['European Organization for Nuclear Research'],
#       'type': 'repository'},
#      'license': 'cc-by',
#      'version': 'submittedVersion'}],
#    'best_oa_location': {'is_oa': True,
#     'landing_page_url': 'https://zenodo.org/record/7951155',
#     'pdf_url': 'https://zenodo.org/record/7951155/files/Report%20on%20the%20Workshop%20on%20Sustainable%20Software%20Sustainability%202021%20%28WoSSS21%29.pdf',
#     'source': {'id': 'https://openalex.org/S4306400562',
#      'display_name': 'Zenodo (CERN European Organization for Nuclear Research)',
#      'issn_l': None,
#      'issn': None,
#      'host_organization': 'https://openalex.org/I67311998',
#      'host_organization_name': 'European Organization for Nuclear Research',
#      'host_organization_lineage': ['https://openalex.org/I67311998'],
#      'host_organization_lineage_names': ['European Organization for Nuclear Research'],
#      'type': 'repository'},
#     'license': 'cc-by',
#     'version': 'submittedVersion'},
#    'grants': [],
#    'referenced_works': [],
#    'related_works': ['https://openalex.org/W1970842528',
#     'https://openalex.org/W1978718146',
#     'https://openalex.org/W2130208464',
#     'https://openalex.org/W2528074251',
#     'https://openalex.org/W3143152107',
#     'https://openalex.org/W3164411944',
#     'https://openalex.org/W4226291783',
#     'https://openalex.org/W4234907370',
#     'https://openalex.org/W4283795720',
#     'https://openalex.org/W4285040687'],
#    'ngrams_url': 'https://api.openalex.org/works/W4378737443/ngrams',
#    'abstract_inverted_index': None,
#    'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4378737443',
#    'counts_by_year': [],
#    'updated_date': '2023-05-31T00:51:10.811905',
#    'created_date': '2023-05-30',
#    'topic_name': ['Workflow',
#     'Environmental science',
#     'Software engineering',
#     'Software'],
#    'group_id': 4},
#   {'id': 'https://openalex.org/W4375860161',
#    'doi': 'https://doi.org/10.5194/egusphere-gc8-hydro-123',
#    'title': 'Towards an Open Digital Twin of Soil-Plant System',
#    'display_name': 'Towards an Open Digital Twin of Soil-Plant System',
#    'publication_year': 2023,
#    'publication_date': '2023-05-08',
#    'ids': {'openalex': 'https://openalex.org/W4375860161',
#     'doi': 'https://doi.org/10.5194/egusphere-gc8-hydro-123'},
#    'language': 'en',
#    'primary_location': {'is_oa': False,
#     'landing_page_url': 'https://doi.org/10.5194/egusphere-gc8-hydro-123',
#     'pdf_url': None,
#     'source': None,
#     'license': None,
#     'version': None},
#    'type': 'posted-content',
#    'open_access': {'is_oa': False,
#     'oa_status': 'closed',
#     'oa_url': None,
#     'any_repository_has_fulltext': False},
#    'authorships': [{'author_position': 'first',
#      'author': {'id': 'https://openalex.org/A2427198476',
#       'display_name': 'Yijian Zeng',
#       'orcid': 'https://orcid.org/0000-0002-2166-5314'},
#      'institutions': [],
#      'is_corresponding': True,
#      'raw_affiliation_string': '',
#      'raw_affiliation_strings': []},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4376224164',
#       'display_name': 'Fakhereh Alidoost',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands eScience Center, Amsterdam, the Netherlands',
#      'raw_affiliation_strings': ['Netherlands eScience Center, Amsterdam, the Netherlands']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A2970027634',
#       'display_name': 'Bart Schilperoort',
#       'orcid': 'https://orcid.org/0000-0003-4487-9822'},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': True,
#      'raw_affiliation_string': 'Netherlands eScience Center, Amsterdam, the Netherlands',
#      'raw_affiliation_strings': ['Netherlands eScience Center, Amsterdam, the Netherlands']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A2941505578',
#       'display_name': 'Yang Liu',
#       'orcid': 'https://orcid.org/0000-0002-1966-8460'},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': True,
#      'raw_affiliation_string': 'Netherlands eScience Center, Amsterdam, the Netherlands',
#      'raw_affiliation_strings': ['Netherlands eScience Center, Amsterdam, the Netherlands']},
#     {'author_position': 'last',
#      'author': {'id': 'https://openalex.org/A4376224165',
#       'display_name': 'Zhongbo Su',
#       'orcid': None},
#      'institutions': [],
#      'is_corresponding': False,
#      'raw_affiliation_string': '',
#      'raw_affiliation_strings': []}],
#    'corresponding_author_ids': ['https://openalex.org/A2427198476',
#     'https://openalex.org/A2970027634',
#     'https://openalex.org/A2941505578'],
#    'corresponding_institution_ids': ['https://openalex.org/I4210095242',
#     'https://openalex.org/I4210095242'],
#    'apc_payment': None,
#    'cited_by_count': 0,
#    'biblio': {'volume': None,
#     'issue': None,
#     'first_page': None,
#     'last_page': None},
#    'is_retracted': False,
#    'is_paratext': False,
#    'concepts': [{'id': 'https://openalex.org/C110872660',
#      'wikidata': 'https://www.wikidata.org/wiki/Q37813',
#      'display_name': 'Ecosystem',
#      'level': 2,
#      'score': 0.60224277},
#     {'id': 'https://openalex.org/C39432304',
#      'wikidata': 'https://www.wikidata.org/wiki/Q188847',
#      'display_name': 'Environmental science',
#      'level': 0,
#      'score': 0.56329846},
#     {'id': 'https://openalex.org/C107826830',
#      'wikidata': 'https://www.wikidata.org/wiki/Q929380',
#      'display_name': 'Environmental resource management',
#      'level': 1,
#      'score': 0.45525277},
#     {'id': 'https://openalex.org/C137176749',
#      'wikidata': 'https://www.wikidata.org/wiki/Q4105337',
#      'display_name': 'Psychological resilience',
#      'level': 2,
#      'score': 0.4355177},
#     {'id': 'https://openalex.org/C132651083',
#      'wikidata': 'https://www.wikidata.org/wiki/Q7942',
#      'display_name': 'Climate change',
#      'level': 2,
#      'score': 0.43236786},
#     {'id': 'https://openalex.org/C58941895',
#      'wikidata': 'https://www.wikidata.org/wiki/Q295865',
#      'display_name': 'Ecosystem services',
#      'level': 3,
#      'score': 0.4316366},
#     {'id': 'https://openalex.org/C2779585090',
#      'wikidata': 'https://www.wikidata.org/wiki/Q3457762',
#      'display_name': 'Resilience (materials science)',
#      'level': 2,
#      'score': 0.42946607},
#     {'id': 'https://openalex.org/C18903297',
#      'wikidata': 'https://www.wikidata.org/wiki/Q7150',
#      'display_name': 'Ecology',
#      'level': 1,
#      'score': 0.266312},
#     {'id': 'https://openalex.org/C86803240',
#      'wikidata': 'https://www.wikidata.org/wiki/Q420',
#      'display_name': 'Biology',
#      'level': 0,
#      'score': 0.091822565},
#     {'id': 'https://openalex.org/C121332964',
#      'wikidata': 'https://www.wikidata.org/wiki/Q413',
#      'display_name': 'Physics',
#      'level': 0,
#      'score': 0.06937763},
#     {'id': 'https://openalex.org/C15744967',
#      'wikidata': 'https://www.wikidata.org/wiki/Q9418',
#      'display_name': 'Psychology',
#      'level': 0,
#      'score': 0.0},
#     {'id': 'https://openalex.org/C542102704',
#      'wikidata': 'https://www.wikidata.org/wiki/Q183257',
#      'display_name': 'Psychotherapist',
#      'level': 1,
#      'score': 0.0},
#     {'id': 'https://openalex.org/C97355855',
#      'wikidata': 'https://www.wikidata.org/wiki/Q11473',
#      'display_name': 'Thermodynamics',
#      'level': 1,
#      'score': 0.0}],
#    'mesh': [],
#    'locations_count': 1,
#    'locations': [{'is_oa': False,
#      'landing_page_url': 'https://doi.org/10.5194/egusphere-gc8-hydro-123',
#      'pdf_url': None,
#      'source': None,
#      'license': None,
#      'version': None}],
#    'best_oa_location': None,
#    'grants': [],
#    'referenced_works': [],
#    'related_works': ['https://openalex.org/W1843763927',
#     'https://openalex.org/W1993905011',
#     'https://openalex.org/W2520357990',
#     'https://openalex.org/W2768343980',
#     'https://openalex.org/W2886547272',
#     'https://openalex.org/W3124931100',
#     'https://openalex.org/W3183550395',
#     'https://openalex.org/W3216901741',
#     'https://openalex.org/W4244357460',
#     'https://openalex.org/W4281638003'],
#    'ngrams_url': 'https://api.openalex.org/works/W4375860161/ngrams',
#    'abstract_inverted_index': {'&amp;lt;p&amp;gt;Climate': [0],
#     'projections': [1],
#     'strongly': [2],
#     'suggest': [3],
#     'that': [4],
#     'the': [5, 14, 46, 54, 62, 77, 90, 103, 113, 128, 131],
#     '2022': [6],
#     'sweltering': [7],
#     'summer': [8],
#     'may': [9],
#     'be': [10, 68],
#     'a': [11, 99, 138],
#     'harbinger': [12],
#     'of': [13, 33, 40, 45, 56, 79, 89, 102, 130, 140],
#     'future': [15],
#     'European': [16],
#     'climate.': [17],
#     'Climate': [18],
#     'extremes': [19],
#     '(e.g.,': [20],
#     'droughts': [21],
#     'and': [22, 29, 52, 73, 116],
#     'heatwaves)': [23],
#     'jeopardize': [24],
#     'terrestrial': [25],
#     'ecosystem': [26, 60],
#     'carbon': [27],
#     'sequestration': [28],
#     'hinder': [30],
#     'EU&amp;#039;s': [31],
#     'goal': [32],
#     'being': [34],
#     'climate-neutral': [35],
#     'by': [36],
#     '2050.': [37],
#     'The': [38, 95],
#     'construction': [39],
#     'an': [41],
#     'open': [42, 142],
#     'digital': [43, 92, 100, 144],
#     'twin': [44],
#     'soil-plant': [47, 91, 96, 104, 114, 132, 143],
#     'system': [48],
#     'helps': [49],
#     'to': [50, 70, 75, 81, 111, 121, 126],
#     'monitor': [51],
#     'predict': [53],
#     'impact': [55],
#     'extreme': [57],
#     'events': [58],
#     'on': [59],
#     'functioning,': [61],
#     'resulting': [63],
#     'information': [64],
#     'from': [65],
#     'which': [66],
#     'can': [67],
#     'used': [69],
#     'recommend': [71],
#     'measures': [72],
#     'policies': [74],
#     'increase': [76],
#     'resilience': [78],
#     'ecosystems': [80],
#     'climate-related': [82],
#     'challenges.': [83],
#     'There': [84],
#     'are': [85],
#     'three': [86],
#     'main': [87],
#     'components': [88],
#     'twin:&amp;amp;#160;': [93],
#     'i)': [94],
#     'model': [97],
#     'for': [98],
#     'representation': [101],
#     'system;': [105],
#     'ii)': [106],
#     'Physics-aware': [107],
#     'machine': [108],
#     'learning': [109],
#     'algorithms': [110],
#     'approximate': [112],
#     'model;': [115],
#     'iii)': [117],
#     'Data': [118],
#     'assimilation': [119],
#     'framework': [120],
#     'digest': [122],
#     'Earth': [123],
#     'Observation': [124],
#     'data': [125],
#     'update': [127],
#     'states': [129],
#     'system.': [133],
#     'This': [134],
#     'paper': [135],
#     'will': [136],
#     'present': [137],
#     'prototype': [139],
#     'this': [141],
#     'twin.&amp;lt;/p&amp;gt;': [145]},
#    'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4375860161',
#    'counts_by_year': [],
#    'updated_date': '2023-05-24T01:09:33.088577',
#    'created_date': '2023-05-10',
#    'topic_name': ['Python (programming language)',
#     'Biology',
#     'Artificial intelligence',
#     'Geology'],
#    'group_id': 0},
#   {'id': 'https://openalex.org/W4368365351',
#    'doi': 'https://doi.org/10.22541/essoar.168319841.11427814/v1',
#    'title': 'Cloud Botany: Shallow cumulus clouds in an ensemble of idealized large-domain large-eddy simulations of the trades',
#    'display_name': 'Cloud Botany: Shallow cumulus clouds in an ensemble of idealized large-domain large-eddy simulations of the trades',
#    'publication_year': 2023,
#    'publication_date': '2023-05-04',
#    'ids': {'openalex': 'https://openalex.org/W4368365351',
#     'doi': 'https://doi.org/10.22541/essoar.168319841.11427814/v1'},
#    'language': 'en',
#    'primary_location': {'is_oa': True,
#     'landing_page_url': 'https://doi.org/10.22541/essoar.168319841.11427814/v1',
#     'pdf_url': 'https://essopenarchive.org/doi/pdf/10.22541/essoar.168319841.11427814',
#     'source': {'id': 'https://openalex.org/S4306402105',
#      'display_name': 'Authorea (Authorea)',
#      'issn_l': None,
#      'issn': None,
#      'host_organization': None,
#      'host_organization_name': None,
#      'host_organization_lineage': [],
#      'host_organization_lineage_names': [],
#      'type': 'repository'},
#     'license': 'cc-by',
#     'version': 'submittedVersion'},
#    'type': 'posted-content',
#    'open_access': {'is_oa': True,
#     'oa_status': 'green',
#     'oa_url': 'https://essopenarchive.org/doi/pdf/10.22541/essoar.168319841.11427814',
#     'any_repository_has_fulltext': True},
#    'authorships': [{'author_position': 'first',
#      'author': {'id': 'https://openalex.org/A2294038268',
#       'display_name': 'Fredrik Jansson',
#       'orcid': 'https://orcid.org/0000-0003-4712-5938'},
#      'institutions': [{'id': 'https://openalex.org/I98358874',
#        'display_name': 'Delft University of Technology',
#        'ror': 'https://ror.org/02e2c7k09',
#        'country_code': 'NL',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'TU Delft',
#      'raw_affiliation_strings': ['TU Delft']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A3204497135',
#       'display_name': 'M. Janssens',
#       'orcid': 'https://orcid.org/0000-0003-2905-6692'},
#      'institutions': [{'id': 'https://openalex.org/I913481162',
#        'display_name': 'Wageningen University & Research',
#        'ror': 'https://ror.org/04qw24q55',
#        'country_code': 'NL',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Wageningen University & Research',
#      'raw_affiliation_strings': ['Wageningen University & Research']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A2134548078',
#       'display_name': 'J. H. Grönqvist',
#       'orcid': 'https://orcid.org/0000-0002-8754-2501'},
#      'institutions': [{'id': 'https://openalex.org/I130217899',
#        'display_name': 'Åbo Akademi University',
#        'ror': 'https://ror.org/029pk6x14',
#        'country_code': 'FI',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Åbo Akademi University',
#      'raw_affiliation_strings': ['Åbo Akademi University']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A1431279656',
#       'display_name': 'A. Pier Siebesma',
#       'orcid': 'https://orcid.org/0000-0002-7751-5999'},
#      'institutions': [{'id': 'https://openalex.org/I98358874',
#        'display_name': 'Delft University of Technology',
#        'ror': 'https://ror.org/02e2c7k09',
#        'country_code': 'NL',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'TU Delft',
#      'raw_affiliation_strings': ['TU Delft']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A2528150126',
#       'display_name': 'Franziska Glassmeier',
#       'orcid': 'https://orcid.org/0000-0002-1132-7821'},
#      'institutions': [{'id': 'https://openalex.org/I98358874',
#        'display_name': 'Delft University of Technology',
#        'ror': 'https://ror.org/02e2c7k09',
#        'country_code': 'NL',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'TU  Delft',
#      'raw_affiliation_strings': ['TU  Delft']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A2591099513',
#       'display_name': 'Jisk Attema',
#       'orcid': 'https://orcid.org/0000-0002-0948-1176'},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands eScience Center',
#      'raw_affiliation_strings': ['Netherlands eScience Center']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4370345620',
#       'display_name': 'Victor Azizi',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands eScience Center',
#      'raw_affiliation_strings': ['Netherlands eScience Center']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A2102210108',
#       'display_name': 'Masaki Satoh',
#       'orcid': 'https://orcid.org/0000-0003-3580-8897'},
#      'institutions': [{'id': 'https://openalex.org/I74801974',
#        'display_name': 'The University of Tokyo',
#        'ror': 'https://ror.org/057zh3y96',
#        'country_code': 'JP',
#        'type': 'education'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'University of Tokyo',
#      'raw_affiliation_strings': ['University of Tokyo']},
#     {'author_position': 'middle',
# ...
#     'conservative': [289],
#     'from': [291],
#     'grids': [293],
#     'Example': [297],
#     'applications': [298],
#     'new': [301, 309, 345],
#     'support': [304, 404],
#     'setups': [311],
#     'predecessor': [313],
#     'versions,': [314],
#     'assessing': [315],
#     'different': [320],
#     'observations,': [323],
#     'CMORization': [324],
#     'contributions': [330],
#     'projects,': [334],
#     'monitoring': [336],
#     'simulations.': [341],
#     'latter,': [344],
#     'general-purpose': [346],
#     'have': [348],
#     'been': [349],
#     'added': [350],
#     'able': [355],
#     'plot': [357],
#     'wide': [359],
#     'range': [360],
#     'variable': [362],
#     'types.': [363],
#     'five': [365],
#     'supported:': [369],
#     'CESM2': [370],
#     '(experimental;': [371],
#     'at': [372],
#     'moment,': [374],
#     'only': [375],
#     'surface': [376],
#     'variables': [377],
#     'available),': [379],
#     'EC-Earth3,': [380],
#     'EMAC,': [381],
#     'ICON,': [382],
#     'IPSL-CM6.': [384],
#     'framework': [387],
#     'implemented': [399],
#     'general': [402],
#     'way,': [403],
#     'other': [406],
#     'easily': [411],
#     'added.': [412]},
#    'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4315649142',
#    'counts_by_year': [],
#    'updated_date': '2023-05-29T03:06:49.219841',
#    'created_date': '2023-01-12',
#    'topic_name': ['Workflow',
#     'Environmental science',
#     'Software engineering',
#     'Software'],
#    'group_id': 4},
#   {'id': 'https://openalex.org/W4378801554',
#    'doi': 'https://doi.org/10.1007/978-1-0716-3239-0_18',
#    'title': 'The PANDORA Software for Anchor-Restrained Peptide:MHC Modeling',
#    'display_name': 'The PANDORA Software for Anchor-Restrained Peptide:MHC Modeling',
#    'publication_year': 2023,
#    'publication_date': '2023-01-01',
#    'ids': {'openalex': 'https://openalex.org/W4378801554',
#     'doi': 'https://doi.org/10.1007/978-1-0716-3239-0_18',
#     'pmid': 'https://pubmed.ncbi.nlm.nih.gov/37258920'},
#    'language': 'en',
#    'primary_location': {'is_oa': False,
#     'landing_page_url': 'https://doi.org/10.1007/978-1-0716-3239-0_18',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S4210172139',
#      'display_name': 'Methods in molecular biology',
#      'issn_l': '1064-3745',
#      'issn': ['1940-6029', '1064-3745'],
#      'host_organization': 'https://openalex.org/P4310319900',
#      'host_organization_name': 'Springer Science+Business Media',
#      'host_organization_lineage': ['https://openalex.org/P4310319965',
#       'https://openalex.org/P4310319900'],
#      'host_organization_lineage_names': ['Springer Nature',
#       'Springer Science+Business Media'],
#      'type': 'journal'},
#     'license': None,
#     'version': None},
#    'type': 'book-chapter',
#    'open_access': {'is_oa': False,
#     'oa_status': 'closed',
#     'oa_url': None,
#     'any_repository_has_fulltext': False},
#    'authorships': [{'author_position': 'first',
#      'author': {'id': 'https://openalex.org/A4378810600',
#       'display_name': 'Dario F. Marzella',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210109357',
#        'display_name': 'Radboud Institute for Molecular Life Sciences',
#        'ror': 'https://ror.org/01yb10j39',
#        'country_code': 'NL',
#        'type': 'facility'},
#       {'id': 'https://openalex.org/I2802934949',
#        'display_name': 'Radboud University Nijmegen Medical Centre',
#        'ror': 'https://ror.org/05wg1m734',
#        'country_code': 'NL',
#        'type': 'healthcare'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Center for Molecular and Biomolecular Informatics, Radboud Institute for Molecular Life Sciences, Radboudumc, Nijmegen, The Netherlands',
#      'raw_affiliation_strings': ['Center for Molecular and Biomolecular Informatics, Radboud Institute for Molecular Life Sciences, Radboudumc, Nijmegen, The Netherlands']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4378810601',
#       'display_name': 'Giulia Crocioni',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210095242',
#        'display_name': 'Netherlands eScience Center',
#        'ror': 'https://ror.org/00rbjv475',
#        'country_code': 'NL',
#        'type': 'nonprofit'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Netherlands eScience Center, Amsterdam, The Netherlands',
#      'raw_affiliation_strings': ['Netherlands eScience Center, Amsterdam, The Netherlands']},
#     {'author_position': 'middle',
#      'author': {'id': 'https://openalex.org/A4348993022',
#       'display_name': 'Farzaneh Meimandi Parizi',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210109357',
#        'display_name': 'Radboud Institute for Molecular Life Sciences',
#        'ror': 'https://ror.org/01yb10j39',
#        'country_code': 'NL',
#        'type': 'facility'},
#       {'id': 'https://openalex.org/I2802934949',
#        'display_name': 'Radboud University Nijmegen Medical Centre',
#        'ror': 'https://ror.org/05wg1m734',
#        'country_code': 'NL',
#        'type': 'healthcare'}],
#      'is_corresponding': False,
#      'raw_affiliation_string': 'Center for Molecular and Biomolecular Informatics, Radboud Institute for Molecular Life Sciences, Radboudumc, Nijmegen, The Netherlands',
#      'raw_affiliation_strings': ['Center for Molecular and Biomolecular Informatics, Radboud Institute for Molecular Life Sciences, Radboudumc, Nijmegen, The Netherlands']},
#     {'author_position': 'last',
#      'author': {'id': 'https://openalex.org/A4378810602',
#       'display_name': 'Li C. Xue',
#       'orcid': None},
#      'institutions': [{'id': 'https://openalex.org/I4210109357',
#        'display_name': 'Radboud Institute for Molecular Life Sciences',
#        'ror': 'https://ror.org/01yb10j39',
#        'country_code': 'NL',
#        'type': 'facility'},
#       {'id': 'https://openalex.org/I2802934949',
#        'display_name': 'Radboud University Nijmegen Medical Centre',
#        'ror': 'https://ror.org/05wg1m734',
#        'country_code': 'NL',
#        'type': 'healthcare'}],
#      'is_corresponding': True,
#      'raw_affiliation_string': 'Center for Molecular and Biomolecular Informatics, Radboud Institute for Molecular Life Sciences, Radboudumc, Nijmegen, The Netherlands',
#      'raw_affiliation_strings': ['Center for Molecular and Biomolecular Informatics, Radboud Institute for Molecular Life Sciences, Radboudumc, Nijmegen, The Netherlands']}],
#    'corresponding_author_ids': ['https://openalex.org/A4378810602'],
#    'corresponding_institution_ids': ['https://openalex.org/I4210109357',
#     'https://openalex.org/I2802934949'],
#    'apc_payment': None,
#    'cited_by_count': 0,
#    'biblio': {'volume': None,
#     'issue': None,
#     'first_page': '251',
#     'last_page': '271'},
#    'is_retracted': False,
#    'is_paratext': False,
#    'concepts': [{'id': 'https://openalex.org/C207936829',
#      'wikidata': 'https://www.wikidata.org/wiki/Q423163',
#      'display_name': 'Major histocompatibility complex',
#      'level': 3,
#      'score': 0.79918593},
#     {'id': 'https://openalex.org/C170627219',
#      'wikidata': 'https://www.wikidata.org/wiki/Q13218497',
#      'display_name': 'MHC class I',
#      'level': 4,
#      'score': 0.63986903},
#     {'id': 'https://openalex.org/C41008148',
#      'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#      'display_name': 'Computer science',
#      'level': 0,
#      'score': 0.5548163},
#     {'id': 'https://openalex.org/C70721500',
#      'wikidata': 'https://www.wikidata.org/wiki/Q177005',
#      'display_name': 'Computational biology',
#      'level': 1,
#      'score': 0.49552214},
#     {'id': 'https://openalex.org/C83464605',
#      'wikidata': 'https://www.wikidata.org/wiki/Q575296',
#      'display_name': 'Antigen presentation',
#      'level': 4,
#      'score': 0.43072766},
#     {'id': 'https://openalex.org/C108249834',
#      'wikidata': 'https://www.wikidata.org/wiki/Q3922363',
#      'display_name': 'Antigen processing',
#      'level': 5,
#      'score': 0.4293887},
#     {'id': 'https://openalex.org/C167672396',
#      'wikidata': 'https://www.wikidata.org/wiki/Q417800',
#      'display_name': 'CD8',
#      'level': 3,
#      'score': 0.42728004},
#     {'id': 'https://openalex.org/C86803240',
#      'wikidata': 'https://www.wikidata.org/wiki/Q420',
#      'display_name': 'Biology',
#      'level': 0,
#      'score': 0.31349632},
#     {'id': 'https://openalex.org/C147483822',
#      'wikidata': 'https://www.wikidata.org/wiki/Q103537',
#      'display_name': 'Antigen',
#      'level': 2,
#      'score': 0.27066636},
#     {'id': 'https://openalex.org/C2776090121',
#      'wikidata': 'https://www.wikidata.org/wiki/Q193529',
#      'display_name': 'T cell',
#      'level': 3,
#      'score': 0.2327244},
#     {'id': 'https://openalex.org/C8891405',
#      'wikidata': 'https://www.wikidata.org/wiki/Q1059',
#      'display_name': 'Immune system',
#      'level': 2,
#      'score': 0.23116595},
#     {'id': 'https://openalex.org/C203014093',
#      'wikidata': 'https://www.wikidata.org/wiki/Q101929',
#      'display_name': 'Immunology',
#      'level': 1,
#      'score': 0.17723632}],
#    'mesh': [{'descriptor_ui': 'D006649',
#      'descriptor_name': 'Histocompatibility Antigens',
#      'qualifier_ui': '',
#      'qualifier_name': None,
#      'is_major_topic': True},
#     {'descriptor_ui': 'D008285',
#      'descriptor_name': 'Major Histocompatibility Complex',
#      'qualifier_ui': '',
#      'qualifier_name': None,
#      'is_major_topic': True},
#     {'descriptor_ui': 'D000818',
#      'descriptor_name': 'Animals',
#      'qualifier_ui': '',
#      'qualifier_name': None,
#      'is_major_topic': False},
#     {'descriptor_ui': 'D015395',
#      'descriptor_name': 'Histocompatibility Antigens Class I',
#      'qualifier_ui': '',
#      'qualifier_name': None,
#      'is_major_topic': False},
#     {'descriptor_ui': 'D015395',
#      'descriptor_name': 'Histocompatibility Antigens Class I',
#      'qualifier_ui': 'Q000235',
#      'qualifier_name': 'genetics',
#      'is_major_topic': False},
#     {'descriptor_ui': 'D010455',
#      'descriptor_name': 'Peptides',
#      'qualifier_ui': '',
#      'qualifier_name': None,
#      'is_major_topic': False},
#     {'descriptor_ui': 'D010455',
#      'descriptor_name': 'Peptides',
#      'qualifier_ui': 'Q000737',
#      'qualifier_name': 'chemistry',
#      'is_major_topic': False},
#     {'descriptor_ui': 'D012984',
#      'descriptor_name': 'Software',
#      'qualifier_ui': '',
#      'qualifier_name': None,
#      'is_major_topic': False}],
#    'locations_count': 2,
#    'locations': [{'is_oa': False,
#      'landing_page_url': 'https://doi.org/10.1007/978-1-0716-3239-0_18',
#      'pdf_url': None,
#      'source': {'id': 'https://openalex.org/S4210172139',
#       'display_name': 'Methods in molecular biology',
#       'issn_l': '1064-3745',
#       'issn': ['1940-6029', '1064-3745'],
#       'host_organization': 'https://openalex.org/P4310319900',
#       'host_organization_name': 'Springer Science+Business Media',
#       'host_organization_lineage': ['https://openalex.org/P4310319965',
#        'https://openalex.org/P4310319900'],
#       'host_organization_lineage_names': ['Springer Nature',
#        'Springer Science+Business Media'],
#       'type': 'journal'},
#      'license': None,
#      'version': None},
#     {'is_oa': False,
#      'landing_page_url': 'https://pubmed.ncbi.nlm.nih.gov/37258920',
#      'pdf_url': None,
#      'source': {'id': 'https://openalex.org/S4306525036',
#       'display_name': 'PubMed',
#       'issn_l': None,
#       'issn': None,
#       'host_organization': 'https://openalex.org/I1299303238',
#       'host_organization_name': 'National Institutes of Health',
#       'host_organization_lineage': ['https://openalex.org/I1299303238'],
#       'host_organization_lineage_names': ['National Institutes of Health'],
#       'type': 'repository'},
#      'license': None,
#      'version': None}],
#    'best_oa_location': None,
#    'grants': [],
#    'referenced_works': ['https://openalex.org/W1970688528',
#     'https://openalex.org/W2007886752',
#     'https://openalex.org/W2093629170',
#     'https://openalex.org/W2130479394',
#     'https://openalex.org/W2132926880',
#     'https://openalex.org/W2323889349',
#     'https://openalex.org/W2399366904',
#     'https://openalex.org/W2444060841',
#     'https://openalex.org/W2597129987',
#     'https://openalex.org/W2754641896',
#     'https://openalex.org/W2919975879',
#     'https://openalex.org/W2995987578',
#     'https://openalex.org/W3024570138',
#     'https://openalex.org/W3036418230',
#     'https://openalex.org/W4229451133',
#     'https://openalex.org/W4245532735'],
#    'related_works': ['https://openalex.org/W142312885',
#     'https://openalex.org/W1998713127',
#     'https://openalex.org/W2023967363',
#     'https://openalex.org/W2097543113',
#     'https://openalex.org/W2131957295',
#     'https://openalex.org/W2147210428',
#     'https://openalex.org/W2150467115',
#     'https://openalex.org/W4281625971',
#     'https://openalex.org/W4296740993',
#     'https://openalex.org/W4313383619'],
#    'ngrams_url': 'https://api.openalex.org/works/W4378801554/ngrams',
#    'abstract_inverted_index': {'Major': [0],
#     'histocompatibility': [1],
#     'complexes': [2, 63],
#     '(MHC)': [3],
#     'play': [4],
#     'a': [5],
#     'key': [6],
#     'role': [7],
#     'in': [8, 13, 68, 135],
#     'the': [9, 27, 45, 69, 97, 103, 124],
#     'immune': [10],
#     'surveillance': [11],
#     'system': [12],
#     'all': [14],
#     'jawed': [15],
#     'vertebrates.': [16],
#     'MHC': [17, 30, 110],
#     'class': [18, 31],
#     'I': [19],
#     'molecules': [20, 111],
#     'randomly': [21],
#     'sample': [22, 33],
#     'cytosolic': [23],
#     'peptides': [24],
#     'from': [25],
#     'inside': [26],
#     'cell,': [28],
#     'while': [29],
#     'II': [32],
#     'exogenous': [34],
#     'peptides.': [35, 115],
#     'Both': [36],
#     'types': [37],
#     'of': [38, 61, 99],
#     'peptide:MHC': [39, 88],
#     'complex': [40],
#     'are': [41],
#     'then': [42],
#     'presented': [43],
#     'on': [44, 106],
#     'cell': [46],
#     'surface': [47],
#     'for': [48, 157],
#     'recognition': [49, 72],
#     'by': [50],
#     'αβ': [51],
#     'T': [52],
#     'cells': [53],
#     '(CD8+': [54],
#     'and': [55, 71, 85, 150],
#     'CD4+,': [56],
#     'respectively).': [57],
#     'The': [58],
#     'three-dimensional': [59],
#     'structure': [60],
#     'such': [62],
#     'can': [64],
#     'give': [65],
#     'crucial': [66],
#     'insights': [67],
#     'presentation': [70],
#     'mechanisms.': [73],
#     'For': [74],
#     'this': [75, 93],
#     'reason,': [76],
#     'softwares': [77],
#     'like': [78],
#     'PANDORA': [79, 101, 116, 129, 140],
#     'have': [80],
#     'been': [81],
#     'developed': [82],
#     'to': [83, 113, 122, 130, 145, 153],
#     'rapidly': [84],
#     'accurately': [86],
#     'generate': [87, 131],
#     '(pMHC)': [89],
#     '3D': [90, 133],
#     'structures.': [91],
#     'In': [92],
#     'chapter,': [94],
#     'we': [95],
#     'describe': [96],
#     'protocol': [98],
#     'PANDORA.': [100],
#     'exploits': [102],
#     'structural': [104],
#     'knowledge': [105],
#     'anchor': [107, 118],
#     'pockets': [108],
#     'that': [109],
#     'use': [112],
#     'dock': [114],
#     'provides': [117],
#     'positions': [119],
#     'as': [120],
#     'restraints': [121],
#     'guide': [123],
#     'modeling': [125],
#     'process.': [126],
#     'This': [127],
#     'allows': [128],
#     'twenty': [132],
#     'models': [134],
#     'just': [136],
#     'about': [137],
#     '5': [138],
#     'min.': [139],
#     'is': [141, 151],
#     'highly': [142],
#     'customizable,': [143],
#     'easy': [144],
#     'install,': [146],
#     'supports': [147],
#     'parallel': [148],
#     'processing,': [149],
#     'suitable': [152],
#     'provide': [154],
#     'large': [155],
#     'datasets': [156],
#     'deep': [158],
#     'learning': [159],
#     'algorithms.': [160]},
#    'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W4378801554',
#    'counts_by_year': [],
#    'updated_date': '2023-06-03T04:28:16.292607',
#    'created_date': '2023-06-01',
#    'topic_name': ['Python (programming language)',
#     'Biology',
#     'Artificial intelligence',
#     'Geology'],
#    'group_id': 0}])
